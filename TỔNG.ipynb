# %% [markdown]
# <a href="https://colab.research.google.com/github/EmsioeB/pythonOOP/blob/main/T%E1%BB%94NG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!wget https://raw.githubusercontent.com/truetype/FreeSerif/master/FreeSerif.ttf # download the FreeSerif font file
#!pip install os-sys
import os
#!pip install reportlab
#from reportlab.lib import colors
#from reportlab.pdfgen import canvas
from datetime import datetime
#from datetime import datetime
#from reportlab.lib.pagesizes import letter
#from reportlab.pdfbase import pdfmetrics
#from reportlab.pdfbase.ttfonts import TTFont
class DoiTuong:
    def __init__(self, id, name):
        self.ma = id
        self.ten = name
    def nhap(self):
        id = input("Nhập mã: ")
        name = input("Nhập tên: ")
        self.ma = id
        self.ten = name
        return id, name
    def sua(self): pass
    def them(self): pass
    def cap_nhat(self): pass
    def xoa(self): pass
    def tim_kiem(self): pass

class SanPham(DoiTuong):
    def __init__(self, id, name, category, quantity, price, describe, image, brand):
        super().__init__(id, name)
        self.loai = category
        self.so_luong = quantity
        self.gia = price
        self.mo_ta = describe
        self.hinh_anh= image
        self.thuong_hieu = brand

    def nhap(self, san_pham_list):
        while True:
            id, name = super().nhap()
            # Kiểm tra xem ID có bị trùng hay không
            if any(sp.ma == id for sp in san_pham_list):
                print(f"Mã sản phẩm '{id}' đã tồn tại. Vui lòng nhập lại!")
            else:
                break
        category = input("Nhập loại sản phẩm : ")
        self.loai = category
        # Ràng buộc kiểm tra kích thước hợp lệ
        quantity = int(input("Nhập số lượng sản phẩm: "))
        self.so_luong = quantity
        while True:
            try:
                price = float(input("Nhập giá sản phẩm: "))
                if price <= 0:
                    print("Giá sản phẩm phải là số dương. Vui lòng nhập lại!")
                else:
                    self.gia = price
                    break
            except ValueError:
                print("Vui lòng nhập một số hợp lệ cho giá sản phẩm!")
        describe = input("Nhập mô tả sản phẩm: ")
        self.mo_ta = describe
        brand = input("Nhập thương hiệu sản phẩm: ")
        self.thuong_hieu = brand
        # Yêu cầu nhập đường dẫn ảnh và kiểm tra
        while True:
            image = input("Nhập đường dẫn ảnh sản phẩm (gõ 'x' nếu không có): ")
            if image.strip() == "x":
                self.hinh_anh = "No image"
                break
            elif os.path.isfile(image):  # Kiểm tra đường dẫn ảnh
                self.hinh_anh = image
                break
            else:
                print("Đường dẫn ảnh không hợp lệ. Vui lòng nhập lại!")
        # Tạo đối tượng sản phẩm và thêm vào danh sách
        san_pham = SanPham(id, name, category, quantity, price, describe, brand, image)
        san_pham_list.append(san_pham)
        print("Sản phẩm đã được thêm!")

    def sua(san_pham_list, id):
        for sp in san_pham_list:
            if sp.ma == id:
                print("Chọn thông tin cần sửa:")
                print("1. Tên sản phẩm")
                print("2. Loại sản phẩm")
                print("3. Số lượng sản phẩm")
                print("4. Giá sản phẩm")
                print("5. Mô tả sản phẩm")
                print("6. Thương hiệu sản phẩm")
                print("7. Đường dẫn ảnh sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '1':
                    sp.ten = input("Nhập tên sản phẩm mới: ")
                elif chon == '2':
                    sp.loai = input("Nhập loại sản phẩm mới: ")
                elif chon == '3':
                    sp.so_luong = int(input("Nhập số lượng sản phẩm mới: "))
                elif chon == '4':
                    sp.gia = float(input("Nhập giá sản phẩm mới: "))
                elif chon == '5':
                    sp.mo_ta = input("Nhập mô tả sản phẩm mới: ")
                elif chon == '6':
                    sp.thuong_hieu = input("Nhập thương hiệu sản phẩm mới: ")
                elif chon == '7':
                    while True:
                        image = input("Nhập đường dẫn ảnh sản phẩm mới: ")
                        if os.path.isfile(image):
                            sp.hinh_anh = image
                            break
                        else:
                            print("Đường dẫn không hợp lệ. Vui lòng nhập lại!")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(san_pham_list, id):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(san_pham_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in san_pham_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                print(f"\nMã: {sp.ma}")
                print(f"Tên: {sp.ten}")
                print(f"Loại: {sp.loai}")
                print(f"Số lượng: {sp.so_luong}")
                print(f"Giá: {sp.gia}")
                print(f"Mô tả: {sp.mo_ta}")
                print(f"Thương hiệu: {sp.thuong_hieu}")
                print(f"Hình ảnh: {sp.hinh_anh}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class NguoiDung(DoiTuong):
    def __init__(self, id, name, mail, role):
        super().__init__(id, name)
        self.email = mail
        self.vai_tro = role

    def nhap(self, nguoi_dung_list):
        while True:
            id, name = super().nhap()
            # Kiểm tra xem ID có bị trùng hay không
            if any(sp.ma == id for sp in nguoi_dung_list):
                print(f"Mã người dùng '{id}' đã tồn tại. Vui lòng nhập lại!")
            else:
                break
        mail = input("Nhập email người dùng: ")
        self.email = mail
        while True:
            role = input("Nhập vai trò người dùng (Quản lý/Thủ kho/Nhân viên kho): ")
            self.vai_tro = role
            if self.vai_tro in ['Quản lý', 'Thủ kho', 'Nhân viên kho']:
                break
            else:
                print("Vai trò không hợp lệ. Vui lòng nhập lại!")
        nguoi_dung = NguoiDung(id, name, mail, role)
        nguoi_dung_list.append(nguoi_dung)
        print("Người dùng đã được thêm!")

    def sua(nguoi_dung_list, id):
        for nd in nguoi_dung_list:
            if nd.ma == id:
                print("Chọn thông tin cần sửa:")
                print("1. Tên người dùng")
                print("2. Email người dùng")
                print("3. Vai trò người dùng")
                chon = input("Chọn chức năng: ")
                if chon == '1':
                    nd.ten = input("Nhập tên người dùng mới: ")
                elif chon == '2':
                    nd.email = input("Nhập email người dùng mới: ")
                elif chon == '3':
                    nd.vai_tro = input("Nhập vai trò người dùng mới (Quản lý/Thủ kho): ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Người dùng đã được sửa!")
                return
        print("Người dùng không tồn tại!")

    def xoa(nguoi_dung_list, id):
        for nd in nguoi_dung_list:
            if nd.ma == id:
                nguoi_dung_list.remove(nd)
                print("Người dùng đã được xóa!")
                return
        print("Người dùng không tồn tại!")

    def tim_kiem(nguoi_dung_list, name):
        name = name.lower()  # Chuyển tên nhập vào thành chữ thường để so sánh không phân biệt hoa thường
        ket_qua = [nd for nd in nguoi_dung_list if name in nd.ten.lower() or nd.ma]  # Tìm tất cả người dùng có tên chứa chuỗi tìm kiếm
        if ket_qua:
            print(f"Tìm thấy {len(ket_qua)} người dùng có từ khóa '{name}':")
            print("-" * 50)
            for i, nd in enumerate(ket_qua, 1):
                print(f"{i}. ID: {nd.ma}")
                print(f"   Tên: {nd.ten}")
                print(f"   Email: {nd.email}")
                print(f"   Vai trò: {nd.vai_tro}")
                print("-" * 50)
        else:
            print(f"Không tìm thấy người dùng nào với từ khóa '{name}'!")

class PhieuNhapKho(DoiTuong):
    def __init__(self, id, name, entry_date, warehouse_import_list, import_money, deliverer, receiver, payment_method, id_ncc):
        super().__init__(id, name)
        self.ngay_nhap = entry_date
        self.danh_sach_nhap = warehouse_import_list
        self.tien_nhap = import_money
        self.nguoi_giao = deliverer
        self.nguoi_nhan = receiver
        self.hinh_thuc_thanh_toan = payment_method
        self.ma_nha_cung_cap = id_ncc

    def nhap(self, phieu_nhap_list, san_pham_list, nha_cung_cap_list,nguoi_dung_list):
        while True:
            id, name = super().nhap()
            # Kiểm tra xem ID có bị trùng hay không
            if any(sp.ma == id for sp in phieu_nhap_list):
                print(f"Phiếu '{id}' đã tồn tại. Vui lòng nhập lại!")
            else:
                break
        while True:
            try:
                ngay_nhap_str = input("Nhập ngày nhập (YYYY-MM-DD): ")
                entry_date = datetime.strptime(ngay_nhap_str, "%Y-%m-%d")
                self.ngay_nhap = entry_date
                break
            except ValueError:
                print("Ngày nhập không hợp lệ. Vui lòng nhập lại theo định dạng YYYY-MM-DD.")
        # Nhập thông tin người giao và người nhận
        deliverer = input("Nhập người giao: ")
        self.nguoi_giao = deliverer
        while True:
            receiver = input("Nhập người nhận: ")
            if any(nd.ten == receiver for nd in nguoi_dung_list):
                self.nguoi_nhan = receiver
                break
            else:
                print("Người nhận không tồn tại trong danh sách người dùng. Vui lòng nhập lại.")
        # Nhập phương thức thanh toán
        payment_method = input("Nhập hình thức thanh toán: ")
        self.hinh_thuc_thanh_toan = payment_method
        while True:
            id_ncc = input("Nhập mã nhà cung cấp: ")
            if any(ncc.ma == id_ncc for ncc in nha_cung_cap_list):  # Kiểm tra mã có tồn tại trong danh sách
                self.ma_nha_cung_cap = id_ncc
                break
            else:
                print("Mã nhà cung cấp không tồn tại! Vui lòng nhập lại.")
        # Nhập danh sách sản phẩm trong phiếu nhập kho
        warehouse_import_list = []
        self.danh_sach_nhap = warehouse_import_list
        import_money = 0  # Khởi tạo tiền nhập kho
        self.tien_nhap = import_money
        while True:
            ma_sp = input("Nhập mã sản phẩm (hoặc 'dừng' để kết thúc): ")
            if ma_sp.lower() == 'dừng':
                break
            so_luong = int(input(f"Nhập số lượng sản phẩm {ma_sp}: "))
            if so_luong < 0:
                print(f"Số lượng sản phẩm {ma_sp} không hợp lệ!")
                continue

            # Kiểm tra xem sản phẩm có trong kho không
            for sp in san_pham_list:
                if sp.ma == ma_sp:
                    sp_copy = SanPham(sp.ma, sp.ten, sp.loai, so_luong, sp.gia, sp.mo_ta, sp.hinh_anh, sp.thuong_hieu )
                    self.danh_sach_nhap.append(sp_copy)
                    self.tien_nhap += sp.gia * so_luong  # Tính tiền nhập kho
                    # Cập nhật số lượng sản phẩm trong kho ngay lập tức
                    sp.so_luong += so_luong
                    print(f"Sản phẩm {sp.ten} đã được nhập. Số lượng mới: {sp.so_luong}")
                    break
                else:
                    print(f"Sản phẩm với mã {sp.ten} không tồn tại trong kho.")
        # Tạo phiếu nhập kho
        phieu = PhieuNhapKho(id, name, entry_date, warehouse_import_list, import_money, deliverer, receiver, payment_method, id_ncc)
        # Hỏi người dùng có muốn sửa thông tin không
        while True:
            sua = input("Bạn có muốn sửa thông tin phiếu nhập kho không? (y/n): ").lower()
            if sua == 'y':
                self.sua(phieu, san_pham_list,nha_cung_cap_list)
                break
            elif sua == 'n':
                print("Phiếu nhập kho đã được lưu!")
                break
            else:
                print("Lựa chọn không hợp lệ, vui lòng nhập 'y' hoặc 'n'.")
        return phieu

    def sua(self, phieu, san_pham_list,nha_cung_cap_list):
        print("Chọn thông tin cần sửa:")
        while True:
            print("1. Tên phiếu nhập kho")
            print("2. Ngày nhập")
            print("3. Người giao")
            print("4. Người nhận")
            print("5. Phương thức thanh toán")
            print("6. Sửa danh sách sản phẩm nhập kho")
            print("7. Mã nhà cung cấp")
            print("0. Thoát")
            chon = input("Chọn chức năng cần sửa (1-6): ")
            if chon == '1':
                phieu.ten = input("Nhập tên phiếu nhập kho mới: ")
            elif chon == '2':
                while True:
                    try:
                        ngay_nhap_str = input("Nhập ngày nhập (YYYY-MM-DD): ")
                        phieu.ngay_nhap = datetime.strptime(ngay_nhap_str, "%Y-%m-%d")
                        break
                    except ValueError:
                        print("Ngày nhập không hợp lệ. Vui lòng nhập lại theo định dạng YYYY-MM-DD.")
            elif chon == '3':
                phieu.nguoi_giao = input("Nhập người giao mới: ")
            elif chon == '4':
                phieu.nguoi_nhan = input("Nhập người nhận mới: ")
            elif chon == '5':
                phieu.hinh_thuc_thanh_toan = input("Nhập phương thức thanh toán mới: ")
            elif chon == '6':
                self.sua_danh_sach_san_pham(phieu, san_pham_list)
            elif chon == '7':
                while True:
                    id_ncc = input("Nhập mã nhà cung cấp mới: ")
                    if any(ncc.ma == id_ncc for ncc in nha_cung_cap_list):  # Kiểm tra mã có tồn tại trong danh sách
                        phieu.ma_nha_cung_cap = id_ncc
                        break
                    else:
                        print("Mã nhà cung cấp không tồn tại! Vui lòng nhập lại.")
            elif chon == '0':
                print("Thoát.")
                break
            else:
                print("Chức năng không hợp lệ!")


    def sua_danh_sach_san_pham(self, phieu, san_pham_list):
        print("Sửa danh sách sản phẩm trong phiếu nhập kho:")
        for i, sp in enumerate(phieu.danh_sach_nhap, 1):
            print(f"{i}. {sp.ten} - Số lượng: {sp.so_luong} - Giá: {sp.gia:,} VND - Tổng tiền: {sp.gia * sp.so_luong} VND")
        try:
            chon = int(input(f"Chọn sản phẩm cần sửa (1 - {len(phieu.danh_sach_nhap)}): "))
            if 1 <= chon <= len(phieu.danh_sach_nhap):
                sp = phieu.danh_sach_nhap[chon - 1]
                so_luong_cu = sp.so_luong
                so_luong_moi = int(input(f"Nhập số lượng mới cho sản phẩm {sp.ten}: "))
                if so_luong_moi < 0:
                    print("Số lượng không thể nhỏ hơn 0!")
                    return
                # Cập nhật lại số lượng sản phẩm trong phiếu nhập kho1
                sp.so_luong = so_luong_moi
                print(f"Số lượng sản phẩm {sp.ten} trong phiếu đã được cập nhật: {sp.so_luong}")
                self.tien_nhap += sp.gia * (so_luong_moi - so_luong_cu)
                print(f"Tổng tiền nhập kho đã được cập nhật: {self.tien_nhap} VND")

                # Cập nhật lại số lượng sản phẩm trong kho
                for kho_sp in san_pham_list:
                    if kho_sp.ma == sp.ma:
                        # Cập nhật số lượng kho theo sự thay đổi của phiếu nhập
                        kho_sp.so_luong += (so_luong_moi - so_luong_cu)
                        print(f"Số lượng sản phẩm trong kho {kho_sp.ten} đã được cập nhật: {kho_sp.so_luong}")
                        break
            else:
                print("Lựa chọn không hợp lệ!")
        except ValueError:
            print("Lựa chọn không hợp lệ!")

    def tim_kiem(self, phieu_list, keyword):
        found = False
        for phieu in phieu_list:
            if keyword.lower() in phieu.ma.lower() or keyword.lower() in phieu.ten.lower():
                print(f"\nID Phiếu: {phieu.ma}")
                print(f"Tên Phiếu: {phieu.ten}")
                print(f"Ngày nhập: {phieu.ngay_nhap.strftime('%Y-%m-%d')}")
                print(f"Người giao: {phieu.nguoi_giao}")
                print(f"Người nhận: {phieu.nguoi_nhan}")
                print(f"Hình thức thanh toán: {phieu.hinh_thuc_thanh_toan}")
                print(f"Tổng tiền nhập kho: {phieu.tien_nhap}")
                print("Danh sách sản phẩm:")
                for sp in phieu.danh_sach_nhap:
                    print(f"  - {sp.ten} - Số lượng: {sp.so_luong} - Giá: {sp.gia} - Tổng tiền: {sp.gia * sp.so_luong}")
                found = True
        if not found:
            print("Không tìm thấy phiếu nhập kho!")

class PhieuXuatKho(DoiTuong):
    def __init__(self, id, name, export_date, warehouse_export_list, export_money, distributor,ticket_creator, receiver, delivery_method):
        super().__init__(id, name)
        self.ngay_xuat = export_date
        self.danh_sach_xuat = warehouse_export_list
        self.tien_xuat = export_money
        self.ma_kenh_phan_phoi = distributor
        self.nguoi_tao = ticket_creator
        self.nguoi_nhan = receiver
        self.hinh_thuc_giao_hang = delivery_method


    def nhap(self,phieu_xuat_list, san_pham_list,nguoi_dung_list, kenh_phan_phoi_list):
        while True:
            id, name = super().nhap()
            # Kiểm tra xem ID có bị trùng hay không
            if any(sp.ma == id for sp in phieu_xuat_list):
                print(f"Phiếu '{id}' đã tồn tại. Vui lòng nhập lại!")
            else:
                break
        while True:
            try:
                export_date_str = input("Nhập ngày xuất (YYYY-MM-DD): ")
                export_date = datetime.strptime(export_date_str, "%Y-%m-%d")
                self.ngay_xuat = export_date
                break
            except ValueError:
                print("Ngày xuất không hợp lệ. Vui lòng nhập lại theo định dạng YYYY-MM-DD.")
        # Nhập thông tin nhà phân phối và người nhận
        while True:
            distributor = input("Nhập mã kênh phân phối: ")
            if any(kp.ma == distributor for kp in kenh_phan_phoi_list):
                self.ma_kenh_phan_phoi = distributor
                break
            else:
                print("Mã kênh phân phối không hợp lệ! Vui lòng nhập lại.")
        receiver = input("Nhập người nhận: ")
        self.nguoi_nhan = receiver
        while True:
            ticket_creator = input("Nhập tên người tạo phiếu: ")
            if any(nd.ten == ticket_creator for nd in nguoi_dung_list):
                self.nguoi_tao = ticket_creator
                break
        # Nhập phương thức giao hàng
        delivery_method = input("Nhập hình thức giao hàng: ")
        self.hinh_thuc_giao_hang = delivery_method
        # Nhập danh sách sản phẩm trong phiếu xuất kho
        self.danh_sach_xuat = warehouse_export_list = []
        export_money = 0  # Khởi tạo tiền xuất kho
        self.tien_xuat = export_money
        while True:
            ma_sp = input("Nhập mã sản phẩm (hoặc 'dừng' để kết thúc): ")
            if ma_sp.lower() == 'dừng':
                break
            so_luong = int(input(f"Nhập số lượng sản phẩm {ma_sp}: "))
            if so_luong <= 0:
                print(f"Số lượng sản phẩm {ma_sp} không hợp lệ!")
                continue

            # Kiểm tra sản phẩm có trong kho không1
            for sp in san_pham_list:
                if sp.ma == ma_sp:
                    if sp.so_luong >= so_luong:
                        sp_copy = SanPham(sp.ma, sp.ten, sp.loai, so_luong, sp.gia, sp.mo_ta, sp.hinh_anh, sp.mau_sac, sp.thuong_hieu)
                        self.danh_sach_xuat.append(sp_copy)
                        self.tien_xuat += sp.gia * so_luong  # Tính tiền xuất kho
                        sp.so_luong -= so_luong  # Giảm số lượng sản phẩm trong kho
                        print(f"Sản phẩm {sp.ten} đã được xuất. Số lượng còn lại: {sp.so_luong}")
                    else:
                        print(f"Số lượng sản phẩm {sp.ten} không đủ trong kho!")
                    break
            else:
                print(f"Sản phẩm với mã {ma_sp} không tồn tại trong kho.")

        # Tạo phiếu xuất kho
        phieu = PhieuXuatKho(id, name, export_date, warehouse_export_list, export_money, distributor, receiver, delivery_method)
        # Hỏi người dùng có muốn sửa thông tin không
        while True:
            sua = input("Bạn có muốn sửa thông tin phiếu xuất kho không? (y/n): ").lower()
            if sua == 'y':
                self.sua(phieu, san_pham_list,kenh_phan_phoi_list)
                break
            elif sua == 'n':
                print("Phiếu xuất kho đã được lưu!")
                break
            else:
                print("Lựa chọn không hợp lệ, vui lòng nhập 'y' hoặc 'n'.")
        return phieu


    def sua(self, phieu, san_pham_list,kenh_phan_phoi_list):
        while True:
            print("Chọn thông tin cần sửa:")
            print("1. Tên phiếu xuất kho")
            print("2. Ngày xuất")
            print("3. Nhà phân phối")
            print("4. Người nhận")
            print("5. Hình thức giao hàng")
            print("6. Sửa danh sách sản phẩm xuất kho")
            print("7. Mã kênh phân phối")
            print("0. Thoát")
            chon = input("Chọn chức năng cần sửa (0-6): ")
            if chon == '1':
                phieu.ten = input("Nhập tên phiếu xuất kho mới: ")
            elif chon == '2':
                while True:
                    try:
                        ngay_xuat_str = input("Nhập ngày xuất mới (YYYY-MM-DD): ")
                        phieu.ngay_xuat = datetime.strptime(ngay_xuat_str, "%Y-%m-%d")
                        break
                    except ValueError:
                        print("Ngày xuất không hợp lệ. Vui lòng nhập lại theo định dạng YYYY-MM-DD.")
            elif chon == '3':
                phieu.nha_phan_phoi = input("Nhập nhà phân phối mới: ")
            elif chon == '4':
                phieu.nguoi_nhan = input("Nhập người nhận mới: ")
            elif chon == '5':
                phieu.hinh_thuc_giao_hang = input("Nhập hình thức giao hàng mới: ")
            elif chon == '6':
                self.sua_danh_sach_san_pham(phieu, san_pham_list)
            elif chon == '7':
                while True:
                    distributor = input("Nhập mã kênh phân phối mới: ")
                    if any(kp.ma == distributor for kp in kenh_phan_phoi_list):
                        phieu.kenh_phan_phoi = distributor
                        break
                    else:
                        print("Mã kênh phân phối không hợp lệ! Vui lòng nhập lại.")
            elif chon == '0':
                print("Thoát.")
                break
            else:
                print("Chức năng không hợp lệ!")

    def sua_danh_sach_san_pham(self,phieu, san_pham_list):
        print("Sửa danh sách sản phẩm trong phiếu xuất kho:")
        for i, sp in enumerate(phieu.danh_sach_xuat, 1):
            print(f"{i}. {sp.ten} - Số lượng: {sp.so_luong} - Giá: {sp.gia} VND - Tổng tiền: {sp.gia * sp.so_luong} VND")
        try:
            chon = int(input(f"Chọn sản phẩm cần sửa (1- {len(phieu.danh_sach_xuat)}): "))

            if 1 <= chon <= len(phieu.danh_sach_xuat):
                sp = phieu.danh_sach_xuat[chon - 1]
                so_luong_cu = sp.so_luong
                so_luong_moi = int(input(f"Nhập số lượng mới cho sản phẩm {sp.ten}: "))
                if so_luong_moi < 0:
                    print("Số lượng không thể nhỏ hơn 0!")
                    return
                # Cập nhật lại số lượng sản phẩm trong phiếu xuất kho
                sp.so_luong = so_luong_moi
                self.tien_xuat += (sp.gia * (so_luong_moi - so_luong_cu))
                print(f"Số lượng sản phẩm {sp.ten} trong phiếu đã được cập nhật: {sp.so_luong}")

                # Cập nhật lại số lượng sản phẩm trong kho
                for kho_sp in san_pham_list:
                    if kho_sp.ma == sp.ma:
                        # Cập nhật số lượng kho theo sự thay đổi của phiếu xuất
                        kho_sp.so_luong -= (so_luong_moi - so_luong_cu)
                        print(f"Số lượng sản phẩm trong kho {kho_sp.ten} đã được cập nhật: {kho_sp.so_luong}")
                        break
            else:
                print("Lựa chọn không hợp lệ!")
        except ValueError:
            print("Lựa chọn không hợp lệ!")

    def tim_kiem(self, phieu_list, keyword):
        found = False
        for phieu in phieu_list:
            if keyword.lower() in phieu.ma.lower() or keyword.lower() in phieu.ten.lower():
                print(f"\nID Phiếu: {phieu.ma}")
                print(f"Tên Phiếu: {phieu.ten}")
                print(f"Ngày xuất: {phieu.ngay_xuat.strftime('%Y-%m-%d')}")
                print(f"Nhà phân phối: {phieu.nha_phan_phoi}")
                print(f"Người nhận: {phieu.nguoi_nhan}")
                print(f"Hình thức giao hàng: {phieu.hinh_thuc_giao_hang}")
                print(f"Tổng tiền xuất kho: {phieu.tien_xuat}")
                print("Danh sách sản phẩm:")
                for sp in phieu.danh_sach_xuat:
                    print(f"  - {sp.ten} - Số lượng: {sp.so_luong} - Giá: {sp.gia} - Tổng tiền: {sp.gia * sp.so_luong}")
                found = True
        if not found:
            print("Không tìm thấy phiếu xuất kho!")

class KenhPhanPhoi(DoiTuong):
    def __init__(self, id, name, address, phone_number):
        super().__init__(id, name)
        self.dia_chi = address
        self.so_dien_thoai = phone_number

    def nhap(self,kenh_phan_phoi_list):
        while True:
            id, name = super().nhap()
            # Kiểm tra xem ID có bị trùng hay không
            if any(sp.ma == id for sp in kenh_phan_phoi_list):
                print(f"Kênh '{id}' đã tồn tại. Vui lòng nhập lại!")
            else:
                break
        address = input("Nhập địa chỉ kênh phân phối: ")
        self.dia_chi = address
        while True:
            phone_number = input("Nhập số điện thoại kênh phân phối: ")
            if phone_number.isdigit() and len(phone_number) == 10:
                self.so_dien_thoai = phone_number
                break
            else:
                print("Số điện thoại không hợp lệ! Vui lòng nhập đúng 10 chữ số.")
        kenh_phan_phoi = KenhPhanPhoi(id, name, address, phone_number)
        kenh_phan_phoi_list.append(kenh_phan_phoi)
        print("kênh phân phối đã được thêm!")

    def sua(kenh_phan_phoi_list, ma):
        for kp in kenh_phan_phoi_list:
            if kp.ma == ma:
                print("Chọn thông tin cần sửa:")
                print("1. Tên kênh phân phối")
                print("2. Địa chỉ kênh phân phối")
                print("3. Số điện thoại kênh phân phối")
                chon = input("Chọn chức năng (1-3): ")
                if chon == '1':
                    kp.ten = input("Nhập tên kênh phân phối mới: ")
                elif chon == '2':
                    kp.dia_chi = input("Nhập địa chỉ kênh phân phối mới: ")
                elif chon == '3':
                    kp.so_dien_thoai = input("Nhập số điện thoại kênh phân phối mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("kênh phân phối đã được sửa!")
                return
        print("kênh phân phối không tồn tại!")

    @staticmethod
    def xoa(kenh_phan_phoi_list, id):
        for kp in kenh_phan_phoi_list:
            if kp.ma == id:
                kenh_phan_phoi_list.remove(kp)
                print("kênh phân phối đã được xóa!")
                return
        print("kênh phân phối không tồn tại!")

    @staticmethod
    def tim_kiem(kenh_phan_phoi_list, keyword):
        found = False
        for kp in kenh_phan_phoi_list:
            if keyword.lower() in kp.ten.lower() or keyword.lower() in kp.dia_chi.lower():
                print(f"\nID: {kp.ma}")
                print(f"Tên: {kp.ten}")
                print(f"Địa chỉ: {kp.dia_chi}")
                print(f"Số điện thoại: {kp.so_dien_thoai}")
                found = True
        if not found:
            print("Không tìm thấy kênh phân phối!")

class NhaCungCap(DoiTuong):
    def __init__(self, id, name, address_supplier_address, phone_number_supplier):
        super().__init__(id, name)
        self.dia_chi_nha_cung_cap = address_supplier_address
        self.so_dien_thoai_nha_cung_cap = phone_number_supplier

    def nhap(self,nha_cung_cap_list, kenh_phan_phoi_list):
        while True:
            id, name = super().nhap()
            # Kiểm tra xem ID có bị trùng hay không
            if any(sp.ma == id for sp in nha_cung_cap_list):
                print(f"Kênh '{id}' đã tồn tại. Vui lòng nhập lại!")
            else:
                break
        address_supplier_address = input("Nhập địa chỉ nhà cung cấp: ")
        self.dia_chi_nha_cung_cap = address_supplier_address
        while True:
            phone_number_supplier = input("Nhập số điện thoại nhà cung cấp: ")

            # Kiểm tra tính hợp lệ của số điện thoại
            if not (phone_number_supplier.isdigit() and len(phone_number_supplier) == 10):
                print("Số điện thoại không hợp lệ! Vui lòng nhập đúng 10 chữ số.")
                continue

            # Kiểm tra số điện thoại đã tồn tại trong danh sách nhà cung cấp hoặc người dùng
            if any(phone_number_supplier == ncc.so_dien_thoai_nha_cung_cap for ncc in nha_cung_cap_list):
                print("Số điện thoại đã tồn tại trong danh sách nhà cung cấp! Vui lòng nhập lại.")
                continue
            if any(phone_number_supplier == kp.so_dien_thoai for kp in kenh_phan_phoi_list):
                print("Số điện thoại đã tồn tại trong danh sách kênh phân phối! Vui lòng nhập lại.")
                continue

            # Nếu hợp lệ và không trùng lặp, gán số điện thoại
            self.so_dien_thoai_nha_cung_cap = phone_number_supplier
            break
        nha_cung_cap = NhaCungCap(id, name, address_supplier_address, phone_number_supplier)
        nha_cung_cap_list.append(nha_cung_cap)
        print("nhà cung cấp đã được thêm!")

    def sua(nha_cung_cap_list, ma):
        for ncc in nha_cung_cap_list:
            if ncc.ma == ma:
                print("Chọn thông tin cần sửa:")
                print("1. Tên nhà cung cấp")
                print("2. Địa chỉ nhà cung cấp")
                print("3. Số điện thoại nhà cung cấp")
                chon = input("Chọn chức năng (1-3): ")
                if chon == '1':
                    ncc.ten = input("Nhập tên nhà cung cấp mới: ")
                elif chon == '2':
                    ncc.dia_chi_nha_cung_cap = input("Nhập địa chỉ nhà cung cấp mới: ")
                elif chon == '3':
                    ncc.so_dien_thoai_nha_cung_cap = input("Nhập số điện thoại nhà cung cấp mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("nhà cung cấp đã được sửa!")
                return
        print("nhà cung cấp không tồn tại!")

    @staticmethod
    def xoa(nha_cung_cap_list, id):
        for ncc in nha_cung_cap_list:
            if ncc.ma == id:
                nha_cung_cap_list.remove(ncc)
                print("nhà cung cấp đã được xóa!")
                return
        print("nhà cung cấp không tồn tại!")

    @staticmethod
    def tim_kiem(nha_cung_cap_list, keyword):
        found = False
        for ncc in nha_cung_cap_list:
            if keyword.lower() in ncc.ten.lower() or keyword.lower() in ncc.dia_chi_nha_cung_cap.lower():
                print(f"\nID: {ncc.ma}")
                print(f"Tên: {ncc.ten}")
                print(f"Địa chỉ: {ncc.dia_chi_nha_cung_cap}")
                print(f"Số điện thoại: {ncc.so_dien_thoai_nha_cung_cap}")
                found = True
        if not found:
            print("Không tìm thấy nhà cung cấp!")

class ThietBiVS (SanPham):
    thiet_bi_vs_list = []
    def __init__(self, id, name, category, quantity, price, describe,image, color, brand):
        super().__init__(id, name, category, quantity, price, describe,image, color, brand)

    def nhap(self):
        super().nhap()
        ThietBiVS.thiet_bi_vs_list.append(self)

    def sua(thiet_bi_vs_list, ma):
        for sp in thiet_bi_vs_list:
            if sp.ma == ma:
                print("Chọn thông tin cần sửa:")
                print("1. Tên sản phẩm")
                print("2. Loại sản phẩm")
                print("3. Số lượng sản phẩm")
                print("4. Giá sản phẩm")
                print("5. Mô tả sản phẩm")
                print("6. Màu sắc sản phẩm")
                print("7. Thương hiệu sản phẩm")
                print("8. Đường dẫn ảnh sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '1':
                    sp.ten = input("Nhập tên sản phẩm mới: ")
                elif chon == '2':
                    sp.loai = input("Nhập loại sản phẩm mới: ")
                elif chon == '3':
                    sp.so_luong = int(input("Nhập số lượng sản phẩm mới: "))
                elif chon == '4':
                    sp.gia = float(input("Nhập giá sản phẩm mới: "))
                elif chon == '5':
                    sp.mo_ta = input("Nhập mô tả sản phẩm mới: ")
                elif chon == '6':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                elif chon == '7':
                    sp.thuong_hieu = input("Nhập thương hiệu sản phẩm mới: ")
                elif chon == '8':
                    while True:
                        image = input("Nhập đường dẫn ảnh sản phẩm mới: ")
                        if os.path.isfile(image):
                            sp.hinh_anh = image
                            break
                        else:
                            print("Đường dẫn không hợp lệ. Vui lòng nhập lại!")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(thiet_bi_vs_list, ma):
        for sp in thiet_bi_vs_list:
            if sp.ma == ma:
                thiet_bi_vs_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(thiet_bi_vs_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in thiet_bi_vs_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                print(f"\nMã: {sp.ma}")
                print(f"Tên: {sp.ten}")
                print(f"Loại: {sp.loai}")
                print(f"Số lượng: {sp.so_luong}")
                print(f"Giá: {sp.gia}")
                print(f"Mô tả: {sp.mo_ta}")
                print(f"Màu sắc: {sp.mau_sac}")
                print(f"Thương hiệu: {sp.thuong_hieu}")
                print(f"Hình ảnh: {sp.hinh_anh}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class BonTieu(ThietBiVS):
    bon_tieu_list = []
    def __init__(self, id, name, category, quantity, price, describe,image, color, brand, flush_system, drain_valve):
        super().__init__(id, name, category, quantity, price, describe,image, color, brand)
        self.he_thong_xa = flush_system
        self.van_xa = drain_valve

    def nhap(self):
        super().nhap()
        self.he_thong_xa = input("Nhập hệ thống xả: ")
        self.van_xa = input("Nhập loại van xả: ")
        BonTieu.bon_tieu_list.append(self)

    def sua(bon_tieu_list, ma):
        for sp in bon_tieu_list:
            if sp.ma == ma:
                super(BonTieu, sp).sua(bon_tieu_list, ma)
                print("9. Hệ thống xả sản phẩm")
                print("10. Van xả sản phẩm")

                chon = input("Chọn chức năng: ")
                if chon == '9':
                    sp.he_thong_xa = input("Nhập hệ thống xả sản phẩm: ")
                elif chon == ('10'):
                    sp.van_xa = input("Nhập van xả sản phẩm: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(bon_tieu_list, ma):
        for sp in bon_tieu_list:
            if sp.ma == ma:
                bon_tieu_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(bon_tieu_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in bon_tieu_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                super(BonTieu, sp).tim_kiem()
                print(f"Hệ thống xả: {sp.he_thong_xa}")
                print(f"Van xả: {sp.van_xa}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class ThietBiNhaBep (SanPham):
    thiet_bi_nha_bep_list = []

    def __init__(self, id, name, category, quantity, price, describe,image, color, brand, features, material, surface_finish):
        super().__init__(id, name, category, quantity, price, describe,image, color, brand)
        self.tinh_nang = features
        self.vat_lieu = material
        self.be_mat = surface_finish

    def nhap(self):
        super().nhap()
        self.tinh_nang = input("Nhập tính năng sản phẩm: ")
        self.vat_lieu = input("Nhập vật liệu sản phẩm: ")
        self.be_mat = input("Nhập bề mặt sản phẩm: ")
        ThietBiVS.thiet_bi_vs_list.append(self)

    def sua(thiet_bi_nha_bep_list, ma):
        for sp in thiet_bi_nha_bep_list:
            if sp.ma == ma:
                super(ThietBiNhaBep, sp).sua(thiet_bi_nha_bep_list, ma)
                print("9. Tính năng sản phẩm")
                print("10. Vật liệu sản phẩm")
                print("11. Bề mặt sản phẩm")

                chon = input("Chọn chức năng: ")
                if chon == "9":
                    sp.tinh_nang = input("Nhập tính năng sản phẩm: ")
                elif chon == "10":
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm: ")
                elif chon == '11':
                    sp.be_mat = input("Nhập bề mặt sản phẩm: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(thiet_bi_nha_bep_list, ma):
        for sp in thiet_bi_nha_bep_list:
            if sp.ma == ma:
                thiet_bi_nha_bep_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(thiet_bi_nha_bep_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in thiet_bi_nha_bep_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                super(ThietBiNhaBep, sp).tim_kiem()
                print(f"Tính năng: {sp.tinh_nang}")
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Bề mặt: {sp.be_mat}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class VoiBep (ThietBiNhaBep):
    voi_bep_list = []
    def __init__(self, id, name, category, quantity, price, describe, image, color, brand, features, material, surface_finish, filter_mesh):
        super().__init__(id, name, category, quantity, price, describe, image, color, brand, features, material, surface_finish)
        self.luoi_loc = filter_mesh

    def nhap(self):
        super().nhap()
        self.luoi_loc = input("Nhập lưới lọc của sản phẩm: ")
        VoiBep.voi_bep_list.append(self)

    def sua(voi_bep_list, ma):
        for sp in voi_bep_list:
            if sp.ma == ma:
                super(VoiBep, sp).sua(voi_bep_list, ma)
                print("9. Tính năng sản phẩm")
                print("10. Vật liệu sản phẩm")
                print("11. Bề mặt sản phẩm")
                print("12. Lưới lọc sản phẩm")

                chon = input("Chọn chức năng: ")
                if chon == "9":
                    sp.tinh_nang = input("Nhập tính năng sản phẩm: ")
                elif chon == "10":
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm: ")
                elif chon == '11':
                    sp.be_mat = input("Nhập bề mặt sản phẩm: ")
                elif chon == '12':
                    sp.luoi_loc = input("Nhập lưới lọc sản phẩm: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(voi_bep_list, id):
        for sp in voi_bep_list:
            if sp.id == id:
                voi_bep_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(voi_bep_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in voi_bep_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                super(ThietBiNhaBep, sp).tim_kiem()
                print(f"Lưới lọc: {sp.luoi_loc}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class ChauRuaChen (ThietBiNhaBep):
    chau_rua_chen_list = []
    def __init__(self, id, name, category, quantity, price, describe, image, color, brand, features, material, surface_finish, surface_dimensions, cutout_dimensions):
        super().__init__(id, name, category, quantity, price, describe, image, color, brand, features, material, surface_finish)
        self.kt_be_mat = surface_dimensions
        self.kt_khoet_da = cutout_dimensions

    def nhap(self):
        super().nhap()
        self.kt_be_mat = input("Nhập kích thước bề mặt: ")
        self.kt_khoet_da = input("Nhập kích thước khoét đá")
        ChauRuaChen.chau_rua_chen_list.append(self)

    def sua(chau_rua_chen_list, ma):
        for sp in chau_rua_chen_list:
            if sp.ma == ma:
                super(ChauRuaChen, sp).sua(chau_rua_chen_list, ma)
                print("12. Kích thước bề mặt sản phẩm")
                print("13. Kích thước khoét đá sản phẩm")

                chon = input("Chọn chức năng: ")
                if chon == '12':
                    sp.kt_be_mat = input("Nhập kích thước bề mặt sản phẩm")
                elif chon == '13':
                    sp.kt_khoet_da = input("Nhập kích thước khoét đá sản phẩm: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(chau_rua_chen_list, ma):
        for sp in chau_rua_chen_list:
            if sp.ma == ma:
                chau_rua_chen_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(chau_rua_chen_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in chau_rua_chen_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                super(GachOpLat, sp).tim_kiem()
                print(f"Kích thước bề mặt: {sp.kt_be_mat}")
                print(f"Kích thước khoét đá: {sp.kt_khoet_da}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class GachOpLat(SanPham):
    gach_list = []
    def __init__(self, id, name, category, quantity, price, describe,image, color, brand, features, dimensions, pattern, surface_finish, glaze_type, tile_type, tile_body, packaging_specification):
        super().__init__(id, name, category, quantity, price, describe,image, color, brand )
        self.tinh_nang = features
        self.kich_thuoc = dimensions
        self.hoa_tiet = pattern
        self.be_mat = surface_finish
        self.loai_men = glaze_type
        self.loai_gach = tile_type
        self.xuong_gach = tile_body
        self.quy_cach_dong_goi = packaging_specification

    def nhap(self, gach_list):
        super().nhap()
        self.tinh_nang = input("Nhập tính năng sản phẩm: ")
        self.kich_thuoc = input("Nhập kích thước sản phẩm: ")
        self.hoa_tiet = input("Nhập họa tiết sản phẩm: ")
        self.be_mat = input("Nhập bề mặt sản phẩm: ")
        self.loai_men = input("Nhập loại men sản phẩm: ")
        self.loai_gach = input("Nhập loại gạch của sản phẩm")
        self.xuong_gach = input("Nhập xương gạch của sản phẩm:")
        self.quy_cach_dong_goi = input("Nhập quy cách đóng gói sản phẩm")
        GachOpLat.gach_list.append(self)

    def sua(gach_list, ma):
        for sp in gach_list:
            if sp.ma == ma:
                super(GachOpLat, sp).sua(gach_list, ma)
                print("9. Tính năng sản phẩm: ")
                print("10. Kích thươc sản phẩm: ")
                print("11. Hoạ tiết sản phẩm: ")
                print("12. Bề mặt sản phẩm: ")
                print("13. Loại men sản phẩm: ")
                print("14. Loại gạch sản phẩm: ")
                print("15. Xương gạch sản phẩm: ")
                print("16. Quy cách đóng gói sản phẩm: ")

                chon = input("Chọn chức năng: ")
                if chon == '9':
                    sp.tinh_nang = input("Nhập tính năng sản phẩm: ")
                elif chon == '10':
                    sp.tinh_nang = input("Nhập kích thước sản phẩm: ")
                elif chon == '11':
                    sp.tinh_nang = input("Nhập họa tiết sản phẩm: ")
                elif chon == '12':
                    sp.tinh_nang = input("Nhập bề mặt sản phẩm: ")
                elif chon == '13':
                    sp.tinh_nang = input("Nhập loại men sản phẩm: ")
                elif chon == '14':
                    sp.tinh_nang = input("Nhập loại gạch sản phẩm: ")
                elif chon == '15':
                    sp.tinh_nang = input("Nhập xương gạch sản phẩm: ")
                elif chon == '16':
                    sp.tinh_nang = input("Nhập quy cách đóng gói sản phẩm: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(gach_list, ma):
        for sp in gach_list:
            if sp.ma == ma:
                gach_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(gach_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in gach_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                super(GachOpLat, sp).tim_kiem()
                print(f"Tính năng: {sp.tinh_nang} ")
                print(f"Kích thước: {sp.kich_thuoc}")
                print(f"Hoạ tiết: {sp.hoa_tiet}")
                print(f"Bề mặt: {sp.be_mat}")
                print(f"Loại men: {sp.loai_men}")
                print(f"Loại gạch: {sp.loai_gach}")
                print(f"Xương gạch: {sp.xuong_gach}")
                print(f"Quy cách đóng gói: {sp.quy_cach_dong_goi}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class BanCau(ThietBiVS):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, flush_system, glaze_technology, flush_technology, flush_mode, water_consumption, voltage, color):
        super().__init__(id, name, category, quantity, price, describe, image, brand)
        self.he_thong_xa = flush_system
        self.cong_nghe_men = glaze_technology
        self.cong_nghe_xa = flush_technology
        self.che_do_xa = flush_mode
        self.luong_nuoc_xa = water_consumption
        self.nguon_dien = voltage
        self.mau_sac = color

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.he_thong_xa = input("Nhập hệ thống xả: ")
        self.cong_nghe_men = input("Nhập công nghệ men: ")
        self.cong_nghe_xa = input("Nhập công nghệ xả: ")
        self.che_do_xa = input("Nhập chế độ xả: ")
        while True:
            try:
                self.luong_nuoc_xa = float(input("Nhập lượng nước xả (L): "))
                break
            except ValueError:
                print("Vui lòng nhập một số hợp lệ.")
        while True:
            try:
                self.nguon_dien = int(input("Nhập nguồn điện (V): "))
                break
            except ValueError:
                print("Vui lòng nhập một số nguyên.")
        self.mau_sac = input("Nhập màu sắc: ")
        sp = BanCau(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.he_thong_xa, self.cong_nghe_men, self.cong_nghe_xa, self.che_do_xa, self.luong_nuoc_xa, self.nguon_dien, self.mau_sac)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Hệ thống xả sản phẩm")
                print("9. Công nghệ men sản phẩm")
                print("10. Công nghệ xả sản phẩm")
                print("11. Chế độ xả sản phẩm")
                print("12. Lượng nước xả sản phẩm")
                print("13. Nguồn điện sản phẩm")
                print("14. Màu sắc sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.he_thong_xa = input("Nhập hệ thống xả sản phẩm mới: ")
                elif chon == '9':
                    sp.cong_nghe_men = input("Nhập công nghệ men sản phẩm mới: ")
                elif chon == '10':
                    sp.cong_nghe_xa = input("Nhập công nghệ xả sản phẩm mới: ")
                elif chon == '11':
                    sp.che_do_xa = input("Nhập chế độ xả sản phẩm mới: ")
                elif chon == '12':
                    while True:
                        try:
                            sp.luong_nuoc_xa = float(input("Nhập lượng nước xả sản phẩm mới: "))
                            break
                        except ValueError:
                            print("Vui lòng nhập một số hợp lệ.")
                elif chon == '13':
                    while True:
                        try:
                            sp.nguon_dien = int(input("Nhập nguồn điện sản phẩm mới: "))
                            break
                        except ValueError:
                            print("Vui lòng nhập một số hợp lệ.")
                elif chon == '14':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Hệ thống xả: {sp.he_thong_xa}")
                print(f"Công nghệ men: {sp.cong_nghe_men}")
                print(f"Công nghệ xả: {sp.cong_nghe_xa}")
                print(f"Chế độ xả: {sp.che_do_xa}")
                print(f"Lượng nước xả: {sp.luong_nuoc_xa}")
                print(f"Nguồn điện: {sp.nguon_dien}")
                print(f"Màu sắc: {sp.mau_sac}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items

class BonTam(ThietBiVS):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, material, dimensions, color):
        super().__init__(id, name, category, quantity, price, describe, image, brand)
        self.vat_lieu = material
        self.kich_thuoc = dimensions
        self.mau_sac = color

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.vat_lieu = input("Nhập vật liệu: ")
        self.kich_thuoc = input("Nhập kích thước (ví dụ: 90x60x70): ")
        self.mau_sac = input("Nhập màu sắc: ")
        sp = BonTam(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.vat_lieu, self.kich_thuoc, self.mau_sac)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Vật liệu sản phẩm")
                print("9. Kích thước sản phẩm")
                print("10. Màu sắc sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm mới: ")
                elif chon == '9':
                    sp.kich_thuoc = input("Nhập kích thước sản phẩm mới (ví dụ: 80x90x70): ")
                elif chon == '10':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Kích thước: {sp.kich_thuoc}")
                print(f"Màu sắc: {sp.mau_sac}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items

class ChauRua(ThietBiVS):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, technology, accessories, color):
        super().__init__(id, name, category, quantity, price, describe, image, brand)
        self.cong_nge = technology
        self.phu_kien_di_kem = accessories
        self.mau_sac = color

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.cong_nghe = input("Nhập công nghệ: ")
        self.phu_kien_di_kem = input("Nhập phụ kiện đi kèm: ")
        self.mau_sac = input("Nhập màu sắc: ")
        sp = ChauRua(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.cong_nghe, self.phu_kien_di_kem, self.mau_sac)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Công nghệ sản phẩm")
                print("9. Phụ kiện đi kèm sản phẩm")
                print("10. Màu sắc sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.cong_nghe = input("Nhập công nghệ sản phẩm mới: ")
                elif chon == '9':
                    sp.phu_kien_di_kem = input("Nhập phụ kiện đi kèm sản phẩm mới: ")
                elif chon == '10':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Công nghệ: {sp.cong_nghe}")
                print(f"Phụ kiện đi kèm: {sp.phu_kien_di_kem}")
                print(f"Màu sắc: {sp.mau_sac}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items

class SenTam(ThietBiVS):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, shower_head, surface_finish, features, material, dimensions, color):
        super().__init__(id, name, category, quantity, price, describe, image, brand)
        self.bat_sen = shower_head
        self.be_mat = surface_finish
        self.tinh_nang = features
        self.vat_lieu = material
        self.kich_thuoc = dimensions
        self.mau_sac = color

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.bat_sen = input("Nhập bát sen: ")
        self.be_mat = input("Nhập bề mặt: ")
        self.tinh_nang = input("Nhập tính năng: ")
        self.vat_lieu = input("Nhập vật liệu: ")
        self.kich_thuoc = input("Nhập kích thước: ")
        self.mau_sac = input("Nhập màu sắc: ")
        sp = SenTam(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.bat_sen, self.be_mat, self.tinh_nang, self.vat_lieu, self.kich_thuoc, self.mau_sac)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Bát sen sản phẩm")
                print("9. Bề mặt sản phẩm")
                print("10. Tính năng sản phẩm")
                print("11. Vật liệu sản phẩm")
                print("12. Kích thước sản phẩm")
                print("13. Màu sắc sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.bat_sen = input("Nhập bát sen sản phẩm mới: ")
                elif chon == '9':
                    sp.be_mat = input("Nhập bề mặt sản phẩm mới: ")
                elif chon == '10':
                    sp.tinh_nang = input("Nhập tính năng sản phẩm mới: ")
                elif chon == '11':
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm mới: ")
                elif chon == '12':
                    sp.kich_thuoc = input("Nhập kích thước sản phẩm mới: ")
                elif chon == '13':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Bát sen: {sp.bat_sen}")
                print(f"Bề mặt: {sp.be_mat}")
                print(f"Tính năng: {sp.tinh_nang}")
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Kích thước: {sp.kich_thuoc}")
                print(f"Màu sắc: {sp.mau_sac}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items

class Voi(ThietBiVS):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, material, color):
        super().__init__(id, name, category, quantity, price, describe, image, brand)
        self.vat_lieu = material
        self.mau_sac = color

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.vat_lieu = input("Nhập vật liệu: ")
        self.mau_sac = input("Nhập màu sắc: ")
        sp = Voi(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.vat_lieu, self.mau_sac)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Vật liệu sản phẩm")
                print("9. Màu sắc sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm mới: ")
                elif chon == '9':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Màu sắc: {sp.mau_sac}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items


class VoiChau(Voi):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, material, color, surface_finish, temperature_mixer, dimensions):
        super().__init__(id, name, category, quantity, price, describe, image, brand, material, color)
        self.be_mat = surface_finish
        self.bo_tron_nhiet_do = temperature_mixer
        self.kich_thuoc = dimensions

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.be_mat = input("Nhập bề mặt: ")
        self.bo_tron_nhiet_do = input("Nhập bộ trộn nhiệt độ: ")
        self.kich_thuoc = input("Nhập kích thước (ví dụ: 90x60x70): ")
        sp = VoiChau(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.material, self.color, self.be_mat, self.bo_tron_nhiet_do, self.kich_thuoc)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Vật liệu sản phẩm")
                print("9. Màu sắc sản phẩm")
                print("10. Bề mặt sản phẩm")
                print("11. Bộ trộn nhiệt độ sản phẩm")
                print("12. Kích thước sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm mới: ")
                elif chon == '9':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                elif chon == '10':
                    sp.be_mat = input("Nhập bề mặt sản phẩm mới: ")
                elif chon == '11':
                    sp.bo_tron_nhiet_do = input("Nhập bộ trộn nhiệt độ sản phẩm mới: ")
                elif chon == '12':
                    sp.kich_thuoc = input("Nhập kích thước sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Màu sắc: {sp.mau_sac}")
                print(f"Bề mặt: {sp.be_mat}")
                print(f"Bộ trộn nhiệt độ: {sp.bo_tron_nhiet_do}")
                print(f"Kích thước: {sp.kich_thuoc}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items


class Xit(Voi):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, material, color, valve_core):
        super().__init__(id, name, category, quantity, price, describe, image, brand, material, color)
        self.van_loi = valve_core

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.van_loi = input("Nhập van lõi: ")
        sp = Xit(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.material, self.color, self.van_loi)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Vật liệu sản phẩm")
                print("9. Màu sắc sản phẩm")
                print("10. Van lõi sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm mới: ")
                elif chon == '9':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                elif chon == '10':
                    sp.van_loi = input("Nhập van lõi sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Màu sắc: {sp.mau_sac}")
                print(f"Van lõi: {sp.van_loi}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items

class PhuKienKhac(SanPham):

    def __init__(self, id, name, category, quantity, price, describe, brand):
        super().__init__(id, name, category, quantity, price, describe, brand)

    def hien_thi_thong_tin(self):
        super().hien_thi_thong_tin()

    @staticmethod
    # Phương thức nhập thông tin sản phẩm
    def nhap_thong_tin_sp(self, san_pham_list):
        while True:
            id = super().nhap_thong_tin_sp()
            if any(sp.ma == id for sp in san_pham_list):
                print(f"Mã sản phẩm '{id}' đã tồn tại. Vui lòng nhập lại!")
            else:
                break
        super().nhap_thong_tin_sp(id, name, category, quantity, price, describe, brand)
        # Tạo đối tượng sản phẩm và thêm vào danh sách
        sp = PhuKienKhac(id, name, category, quantity, price, describe, brand)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách")

    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")


    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

class GaThoatSan(PhuKienKhac):
    def __init__(self, id, name, category, quantity, price, describe, brand):
        super().__init__(id, name, category, quantity, price, describe, brand)

    def hien_thi_thong_tin(self):
        return super().hien_thi_thong_tin()

    @staticmethod
    # Phương thức nhập thông tin sản phẩm
    def nhap_thong_tin_sp(self, san_pham_list):
        while True:
            id = super().nhap_thong_tin_sp()
            if any(sp.ma == id for sp in san_pham_list):
                print(f"Mã sản phẩm '{id}' đã tồn tại. Vui lòng nhập lại!")
            else:
                break
        super().nhap_thong_tin_sp(id, name, category, quantity, price, describe, brand)
        sp = GaThoatSan(id, name, category, quantity, price, describe, brand)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách")

    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

class Guong(PhuKienKhac):
    kich_thuoc = ''
    hinh_dang = ''


    def __init__(self, id, name, category, quantity, price, describe, brand, material, shape):
        super().__init__(id, name, category, quantity, price, describe, brand)
        self.kich_thuoc = material
        self.hinh_dang = shape

    @staticmethod
    def hien_thi_thong_tin(self):
        super().hien_thi_thong_tin()
        print(f"Kích thước: {self.kich_thuoc}")
        print("\n".join([
            f"{attr.replace('_', ' ').capitalize()}: {value}"
            for attr, value in self.__dict__.items()
            if value  # Chỉ hiển thị thuộc tính có giá trị
        ]))

    @staticmethod
    #Phương thức nhập thông tin sản phẩm
    def nhap_thong_tin_sp(self, san_pham_list):
        material = input(f"Nhập kích thước sản phẩm: ")
        shape = input("Nhập hình dạng sản phẩm: ")
        self.kich_thuoc = material
        sp = Guong(id, name, category, quantity, price, describe, brand, material, shape)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    @staticmethod
    # Phương thức sửa thông tin sản phẩm
    def sua_thong_tin_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                print("Chọn thông tin cần sửa: ")
                print("1. Kích thước")
                chon = input("Chọn thông tin cần sửa: ")
                if chon == '1':
                    sp.kich_thuoc = input("Nhập kích thước mới: ")
                elif chon == '2':
                    sp.hinh_dang = input("Nhập hình dạng mới: ")
                else:
                    print("Thông tin cần sửa không hợp lệ!")
                    return
                print("Đã cập nhật thông tin sản phẩm!")
                return
        print("Sản phẩm không tồn tại")

    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

class LoGiayVeSinh(PhuKienKhac):
    def __init__(self, id, name, category, quantity, price, describe, brand):
        super().__init__(id, name, category, quantity, price, describe, brand)

    def hien_thi_thong_tin(self):
        super().hien_thi_thong_tin()

    def nhap_thong_tin_sp(self, san_pham_list):
        super().nhap_thong_tin_sp(id, name, category, quantity, price, describe, brand)
        sp = LoGiayVeSinh(id, name, category, quantity, price, describe, brand)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách")

    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

class NapRuaDienTu(PhuKienKhac):
    nap_bet = ''
    voi_phun = ''
    che_do_xa = ''
    tinh_nang = ''

    def __init__(self, id, name, category, quantity, price, describe, brand, nozzle, features, toilet_seat, flush_technology):
        super().__init__(id, name, category, quantity, price, describe, brand)
        self.nap_bet = toilet_seat
        self.voi_phun = nozzle
        self.che_do_xa = flush_technology
        self.tinh_nang = features

    def hien_thi_thong_tin(self):
        super().hien_thi_thong_tin()
        print(f"Nắp bệt: {self.nap_bet}")
        print(f"Vòi phun: {self.voi_phun}")
        print(f"Chế độ: {self.che_do_xa}")
        print(f"Tính năng: {self.tinh_nang}")

    def nhap_thong_tin_sp(self, san_pham_list):
        super().nhap_thong_tin_sp(san_pham_list)
        toilet_seat = input("Nhập loại nắp bệt của sản phẩm: ")
        self.nap_bet = toilet_seat
        nozzle = input("Nhập loại vòi phun của sản phẩm")
        self.voi_phun = nozzle
        flush_technology = input("Nhập chế độ xả của sản phẩm: ")
        self.che_do_xa = flush_technology
        features = input("Nhập tính năng của sản phẩm: ")
        self.tinh_nang = features
        sp = NapRuaDienTu(id, name, category, quantity, price, describe, brand, nozzle, toilet_seat, features, flush_technology)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm!")

    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

    @staticmethod
    # Phương thức sửa thông tin sản phẩm
    def sua_thong_tin_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                print("Chọn thông tin cần sửa: ")
                print("1. Nắp bệt")
                print("2. Vòi phun")
                print("3. Chế độ xả")
                print("4. TÍnh năng")
                chon = input("Chọn thông tin cần sửa: ")
                if chon == '1':
                    sp.nap_bet = input("Nhập loại nắp bệt mới: ")
                elif chon == '2':
                    sp.voi_phun = input("Nhập loại vòi phun mới: ")
                elif chon == '3':
                    sp.che_do_xa = input("Nhập chế độ xả mới: ")
                elif chon == '4':
                    sp.tinh_nang = input("Nhập tính năng mới: ")
                else:
                    print("Thông tin cần sửa không hợp lệ!")
                    return
                print("Đã cập nhật thông tin sản phẩm!")
                return
        print("Sản phẩm không tồn tại")


class PhuKien(PhuKienKhac):
    chat_lieu = ''


    def __init__(self, id, name, category, quantity, price, describe, brand, material):
        super().__init__(id, name, category, quantity, price, describe, brand)
        self.chat_lieu = material


    def hien_thi_thong_tin(self):
        super().hien_thi_thong_tin()
        print(f"Chất liệu: {self.chat_lieu}")


    @staticmethod
    def nhap_thong_tin_sp(self, san_pham_list):
        super().nhap_thong_tin_sp(san_pham_list)
        material = input("Nhập chất liệu của sản phẩm: ")
        self.chat_lieu = material
        sp = PhuKien(id, name, category, quantity, price, describe, brand, material)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm!")


    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")


    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua


    @staticmethod
    # Phương thức sửa thông tin sản phẩm
    def sua_thong_tin_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                print("Chọn thông tin cần sửa: ")
                print("1. Chất liệu")
                chon = input("Chọn thông tin cần sửa: ")
                if chon == '1':
                    sp.chat_lieu = input("Nhập loại nắp bệt mới: ")
                else:
                    print("Thông tin cần sửa không hợp lệ!")
                    return
                print("Đã cập nhật thông tin sản phẩm!")
                return
        print("Sản phẩm không tồn tại")


class Menu:
    def __init__(self):
        self.san_pham_list = []
        self.nguoi_dung_list = []
        self.phieu_nhap_list = []
        self.phieu_xuat_list = []
        self.kenh_list = []
        self.nha_cung_cap_list = []


    def hien_thi_menu(self):
        print("\n--- CHƯƠNG TRÌNH QUẢN LÝ KHO HÀNG ---")
        print("1. Quản lý sản phẩm")
        print("2. Quản lý người dùng")
        print("3. Quản lý phiếu nhập kho")
        print("4. Quản lý phiếu xuất kho")
        print("5. Quản lý kênh phân phối")
        print("6. Quản lý nhà cung cấp")
        print("0. Thoát chương trình")

    def chon_menu(self):
        while True:
            self.hien_thi_menu()
            chon = input("Chọn chức năng: ")
            if chon == '1':
                self.quan_ly_san_pham()
            elif chon == '2':
                self.quan_ly_nguoi_dung()
            elif chon == '3':
                self.quan_ly_phieu_nhap()
            elif chon == '4':
                self.quan_ly_phieu_xuat()
            elif chon == '5':
                self.quan_ly_kenh()
            elif chon == '6':
                self.quan_ly_nha_cung_cap()
            elif chon == '0':
                print("Thoát chương trình.")
                break
            else:
                print("Chức năng không hợp lệ. Vui lòng chọn lại.")

    def quan_ly_san_pham(self):
        print("\n--- QUẢN LÝ SẢN PHẨM ---")
        while True:
            print("1. Nhập sản phẩm")
            print("2. Sửa sản phẩm")
            print("3. Tìm kiếm sản phẩm")
            print("4. Xóa sản phẩm")
            print("5. Quay lại")
            chon = input("Chọn chức năng: ")
            if chon == '1':
                san_pham = SanPham(None, None, None, None, None, None, None, None)
                san_pham.nhap(self.san_pham_list)
            elif chon == '2':
                ma = input("Nhập mã sản phẩm cần sửa: ")
                SanPham.sua(self.san_pham_list, ma)
            elif chon == '3':
                ten = input("Nhập tên hoặc mã sản phẩm cần tìm: ")
                SanPham.tim_kiem(self.san_pham_list, ten)
            elif chon == '4':
                ma = input("Nhập mã sản phẩm cần xóa: ")
                SanPham.xoa(self.san_pham_list, ma)
            elif chon == '5':
                break
            else:
                print("Chức năng không hợp lệ.")

    def quan_ly_nguoi_dung(self):
        print("\n--- QUẢN LÝ NGƯỜI DÙNG ---")
        while True:
            print("1. Nhập người dùng")
            print("2. Sửa người dùng")
            print("3. Tìm kiếm người dùng")
            print("4. Xóa người dùng")
            print("5. Quay lại")
            chon = input("Chọn chức năng: ")
            if chon == '1':
                nguoi_dung = NguoiDung(None, None, None, None)
                nguoi_dung.nhap(self.nguoi_dung_list)
            elif chon == '2':
                ma = input("Nhập mã người dùng cần sửa: ")
                NguoiDung.sua(self.nguoi_dung_list, ma)
            elif chon == '3':
                ten = input("Nhập tên hoặc mã người dùng cần tìm: ")
                NguoiDung.tim_kiem(self.nguoi_dung_list, ten)
            elif chon == '4':
                ma = input("Nhập mã người dùng cần xóa: ")
                NguoiDung.xoa(self.nguoi_dung_list, ma)
            elif chon == '5':
                break
            else:
                print("Chức năng không hợp lệ.")

    def quan_ly_phieu_nhap(self):
        while True:
            print("\n--- QUẢN LÝ PHIẾU NHẬP KHO ---")
            print("1. Nhập phiếu nhập kho")
            print("2. Xem phiếu nhập kho")
            print("3. Quay lại")
            chon = input("Chọn chức năng: ")
            if chon == '1':
                phieu = PhieuNhapKho(None, None, None, None, None, None, None, None, None)
                phieu.nhap(self.phieu_nhap_list, self.san_pham_list,self.nha_cung_cap_list,self.nguoi_dung_list)
                self.phieu_nhap_list.append(phieu)
            elif chon == '2':
                keyword = input("Nhập từ khóa tìm kiếm: ")
                for phieu in self.phieu_nhap_list:
                    phieu.tim_kiem(self.phieu_nhap_list, keyword)
            elif chon == '3':
                break
            else:
                print("Chức năng không hợp lệ!")

    def quan_ly_phieu_xuat(self):
        while True:
            print("\n--- QUẢN LÝ PHIẾU XUẤT KHO ---")
            print("1. Nhập phiếu xuất kho")
            print("2. Xem phiếu xuất kho")
            print("3. Quay lại")
            chon = input("Chọn chức năng: ")
            if chon == '1':
                phieu = PhieuXuatKho(None, None, None, None, None, None, None, None, None)
                phieu.nhap(self.phieu_xuat_list, self.san_pham_list,self.kenh_phan_phoi_list,self.nguoi_dung_list) # Call nhap on the instance
                self.phieu_xuat_list.append(phieu)
            elif chon == '2':
                keyword = input("Nhập từ khóa tìm kiếm: ")  # Get keyword from user
                for phieu in self.phieu_xuat_list:
                    phieu.tim_kiem(self.phieu_xuat_list, keyword)
            elif chon == '3':
                break
            else:
                print("Chức năng không hợp lệ!")

    def quan_ly_kenh(self):
        print("\n--- QUẢN LÝ KÊNH PHÂN PHỐI ---")
        while True:
            print("1. Thêm kênh phân phối")
            print("2. Sửa thông tin kênh phân phối")
            print("3. Xóa kênh phân phối")
            print("4. Tìm kiếm kênh phân phối")
            print("5. Hiển thị tất cả kênh phân phối")
            print("0. Thoát")
            chon = input("Chọn chức năng (0-5): ")
            if chon == '1':
                KenhPhanPhoi(None, None, None, None).nhap(self.kenh_list)
            elif chon == '2':
                ma = input("Nhập ID kênh phân phối cần sửa: ")
                KenhPhanPhoi.sua(self.kenh_list, ma)
            elif chon == '3':
                ma = input("Nhập ID kênh phân phối cần xóa: ")
                KenhPhanPhoi.xoa(self.kenh_list, ma)
            elif chon == '4':
                keyword = input("Nhập từ khóa tìm kiếm: ")
                KenhPhanPhoi.tim_kiem(self.kenh_list, keyword)
            elif chon == '5':
                for kp in self.kenh_list:
                    print(f"\nID: {kp.ma}\nTên: {kp.ten}\nĐịa chỉ: {kp.dia_chi}\nSố điện thoại: {kp.so_dien_thoai}")
            elif chon == '0':
                print("Thoát chương trình.")
                break
            else:
                print("Chức năng không hợp lệ!")

    def quan_ly_nha_cung_cap(self):
        print("\n--- QUẢN LÝ NHÀ CUNG CẤP ---")
        while True:
            print("1. Thêm nhà cung cấp")
            print("2. Sửa thông tin nhà cung cấp")
            print("3. Xóa nhà cung cấp")
            print("4. Tìm kiếm nhà cung cấp")
            print("5. Hiển thị tất cả nhà cung cấp")
            print("0. Thoát")
            chon = input("Chọn chức năng (0-5): ")
            if chon == '1':
                NhaCungCap(None, None, None, None).nhap(self.nha_cung_cap_list,self.kenh_list)
            elif chon == '2':
                ma = input("Nhập ID nhà cung cấp cần sửa: ")
                NhaCungCap.sua(self.nha_cung_cap_list, ma)
            elif chon == '3':
                ma = input("Nhập ID nhà cung cấp cần xóa: ")
                NhaCungCap.xoa(self.nha_cung_cap_list, ma)
            elif chon == '4':
                keyword = input("Nhập từ khóa tìm kiếm: ")
                NhaCungCap.tim_kiem(self.nha_cung_cap_list, keyword)
            elif chon == '5':
                for ncc in self.nha_cung_cap_list:
                    print(f"\nID: {ncc.ma}\nTên: {ncc.ten}\nĐịa chỉ: {ncc.dia_chi_nha_cung_cap}\nSố điện thoại: {ncc.so_dien_thoai_nha_cung_cap}")
            elif chon == '0':
                print("Thoát chương trình.")
                break
            else:
                print("Chức năng không hợp lệ!")

# Khởi tạo chương trình và menu
quan_ly_kho = Menu()
quan_ly_kho.chon_menu()


import os
class DoiTuong:
    def __init__(self, id, name):
        self.ma = id
        self.ten = name
    def nhap(self):
        id = input("Nhập mã: ")
        name = input("Nhập tên: ")
        self.ma = id
        self.ten = name
        return id, name
    def sua(self): pass
    def them(self): pass
    def cap_nhat(self): pass
    def xoa(self): pass
    def tim_kiem(self): pass

class SanPham(DoiTuong):
    def __init__(self, id, name, category, quantity, price, describe,image, brand):
        super().__init__(id, name)
        self.loai = category
        self.so_luong = quantity
        self.gia = price
        self.mo_ta = describe
        self.hinh_anh= image
        self.thuong_hieu = brand

    def nhap(self, san_pham_list):
        while True:
            id, name = super().nhap()
            # Kiểm tra xem ID có bị trùng hay không
            if any(sp.ma == id for sp in san_pham_list):
                print(f"Mã sản phẩm '{id}' đã tồn tại. Vui lòng nhập lại!")
            else:
                break
        category = input("Nhập loại sản phẩm: ")
        self.loai = category
        quantity = int(input("Nhập số lượng sản phẩm: "))
        self.so_luong = quantity
        price = float(input("Nhập giá sản phẩm: "))
        self.gia = price
        describe = input("Nhập mô tả sản phẩm: ")
        self.mo_ta = describe
        brand = input("Nhập thương hiệu sản phẩm: ")
        self.thuong_hieu = brand
        # Yêu cầu nhập đường dẫn ảnh và kiểm tra
        while True:
            image = input("Nhập đường dẫn ảnh sản phẩm (gõ 'x' nếu không có): ")
            if image.strip() == "x":
                self.hinh_anh = "No image"
                break
            elif os.path.isfile(image):  # Kiểm tra đường dẫn ảnh
                self.hinh_anh = image
                break
            else:
                print("Đường dẫn ảnh không hợp lệ. Vui lòng nhập lại!")
        # Tạo đối tượng sản phẩm và thêm vào danh sách
        san_pham = SanPham(id, name, category, quantity, price, describe, brand, image)
        san_pham_list.append(san_pham)
        print("Sản phẩm đã được thêm!")

    def sua(san_pham_list, id):
        for sp in san_pham_list:
            if sp.ma == id:
                print("Chọn thông tin cần sửa:")
                print("1. Tên sản phẩm")
                print("2. Loại sản phẩm")
                print("3. Số lượng sản phẩm")
                print("4. Giá sản phẩm")
                print("5. Mô tả sản phẩm")
                print("6. Thương hiệu sản phẩm")
                print("7. Đường dẫn ảnh sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '1':
                    sp.ten = input("Nhập tên sản phẩm mới: ")
                elif chon == '2':
                    sp.loai = input("Nhập loại sản phẩm mới: ")
                elif chon == '3':
                    sp.so_luong = int(input("Nhập số lượng sản phẩm mới: "))
                elif chon == '4':
                    sp.gia = float(input("Nhập giá sản phẩm mới: "))
                elif chon == '5':
                    sp.mo_ta = input("Nhập mô tả sản phẩm mới: ")
                elif chon == '6':
                    sp.thuong_hieu = input("Nhập thương hiệu sản phẩm mới: ")
                elif chon == '7':
                    while True:
                        image = input("Nhập đường dẫn ảnh sản phẩm mới: ")
                        if os.path.isfile(image):
                            sp.hinh_anh = image
                            break
                        else:
                            print("Đường dẫn không hợp lệ. Vui lòng nhập lại!")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(san_pham_list, id):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(san_pham_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in san_pham_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                print(f"\nMã: {sp.ma}")
                print(f"Tên: {sp.ten}")
                print(f"Loại: {sp.loai}")
                print(f"Số lượng: {sp.so_luong}")
                print(f"Giá: {sp.gia}")
                print(f"Mô tả: {sp.mo_ta}")
                print(f"Màu sắc: {sp.mau_sac}")
                print(f"Thương hiệu: {sp.thuong_hieu}")
                print(f"Hình ảnh: {sp.hinh_anh}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class ThietBiVS (SanPham):
    thiet_bi_vs_list = []
    def __init__(self, id, name, category, quantity, price, describe,image, color, brand):
        super().__init__(id, name, category, quantity, price, describe,image, color, brand)

    def nhap(self):
        super().nhap()
        ThietBiVS.thiet_bi_vs_list.append(self)

    def sua(thiet_bi_vs_list, ma):
        for sp in thiet_bi_vs_list:
            if sp.ma == ma:
                print("Chọn thông tin cần sửa:")
                print("1. Tên sản phẩm")
                print("2. Loại sản phẩm")
                print("3. Số lượng sản phẩm")
                print("4. Giá sản phẩm")
                print("5. Mô tả sản phẩm")
                print("6. Màu sắc sản phẩm")
                print("7. Thương hiệu sản phẩm")
                print("8. Đường dẫn ảnh sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '1':
                    sp.ten = input("Nhập tên sản phẩm mới: ")
                elif chon == '2':
                    sp.loai = input("Nhập loại sản phẩm mới: ")
                elif chon == '3':
                    sp.so_luong = int(input("Nhập số lượng sản phẩm mới: "))
                elif chon == '4':
                    sp.gia = float(input("Nhập giá sản phẩm mới: "))
                elif chon == '5':
                    sp.mo_ta = input("Nhập mô tả sản phẩm mới: ")
                elif chon == '6':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                elif chon == '7':
                    sp.thuong_hieu = input("Nhập thương hiệu sản phẩm mới: ")
                elif chon == '8':
                    while True:
                        image = input("Nhập đường dẫn ảnh sản phẩm mới: ")
                        if os.path.isfile(image):
                            sp.hinh_anh = image
                            break
                        else:
                            print("Đường dẫn không hợp lệ. Vui lòng nhập lại!")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(thiet_bi_vs_list, ma):
        for sp in thiet_bi_vs_list:
            if sp.ma == ma:
                thiet_bi_vs_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(thiet_bi_vs_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in thiet_bi_vs_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                print(f"\nMã: {sp.ma}")
                print(f"Tên: {sp.ten}")
                print(f"Loại: {sp.loai}")
                print(f"Số lượng: {sp.so_luong}")
                print(f"Giá: {sp.gia}")
                print(f"Mô tả: {sp.mo_ta}")
                print(f"Màu sắc: {sp.mau_sac}")
                print(f"Thương hiệu: {sp.thuong_hieu}")
                print(f"Hình ảnh: {sp.hinh_anh}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class BonTieu(ThietBiVS):
    bon_tieu_list = []
    def __init__(self, id, name, category, quantity, price, describe,image, color, brand, flush_system, drain_valve):
        super().__init__(id, name, category, quantity, price, describe,image, color, brand)
        self.he_thong_xa = flush_system
        self.van_xa = drain_valve

    def nhap(self):
        super().nhap()
        self.he_thong_xa = input("Nhập hệ thống xả: ")
        self.van_xa = input("Nhập loại van xả: ")
        BonTieu.bon_tieu_list.append(self)

    def sua(bon_tieu_list, ma):
        for sp in bon_tieu_list:
            if sp.ma == ma:
                super(BonTieu, sp).sua(bon_tieu_list, ma)
                print("9. Hệ thống xả sản phẩm")
                print("10. Van xả sản phẩm")

                chon = input("Chọn chức năng: ")
                if chon == '9':
                    sp.he_thong_xa = input("Nhập hệ thống xả sản phẩm: ")
                elif chon == ('10'):
                    sp.van_xa = input("Nhập van xả sản phẩm: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(bon_tieu_list, ma):
        for sp in bon_tieu_list:
            if sp.ma == ma:
                bon_tieu_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(bon_tieu_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in bon_tieu_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                super(BonTieu, sp).tim_kiem()
                print(f"Hệ thống xả: {sp.he_thong_xa}")
                print(f"Van xả: {sp.van_xa}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class ThietBiNhaBep (SanPham):
    thiet_bi_nha_bep_list = []

    def __init__(self, id, name, category, quantity, price, describe,image, color, brand, features, material, surface_finish):
        super().__init__(id, name, category, quantity, price, describe,image, color, brand)
        self.tinh_nang = features
        self.vat_lieu = material
        self.be_mat = surface_finish

    def nhap(self):
        super().nhap()
        self.tinh_nang = input("Nhập tính năng sản phẩm: ")
        self.vat_lieu = input("Nhập vật liệu sản phẩm: ")
        self.be_mat = input("Nhập bề mặt sản phẩm: ")
        ThietBiVS.thiet_bi_vs_list.append(self)

    def sua(thiet_bi_nha_bep_list, ma):
        for sp in thiet_bi_nha_bep_list:
            if sp.ma == ma:
                super(ThietBiNhaBep, sp).sua(thiet_bi_nha_bep_list, ma)
                print("9. Tính năng sản phẩm")
                print("10. Vật liệu sản phẩm")
                print("11. Bề mặt sản phẩm")

                chon = input("Chọn chức năng: ")
                if chon == "9":
                    sp.tinh_nang = input("Nhập tính năng sản phẩm: ")
                elif chon == "10":
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm: ")
                elif chon == '11':
                    sp.be_mat = input("Nhập bề mặt sản phẩm: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(thiet_bi_nha_bep_list, ma):
        for sp in thiet_bi_nha_bep_list:
            if sp.ma == ma:
                thiet_bi_nha_bep_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(thiet_bi_nha_bep_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in thiet_bi_nha_bep_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                super(ThietBiNhaBep, sp).tim_kiem()
                print(f"Tính năng: {sp.tinh_nang}")
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Bề mặt: {sp.be_mat}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class VoiBep (ThietBiNhaBep):
    voi_bep_list = []
    def __init__(self, id, name, category, quantity, price, describe, image, color, brand, features, material, surface_finish, filter_mesh):
        super().__init__(id, name, category, quantity, price, describe, image, color, brand, features, material, surface_finish)
        self.luoi_loc = filter_mesh

    def nhap(self):
        super().nhap()
        self.luoi_loc = input("Nhập lưới lọc của sản phẩm: ")
        VoiBep.voi_bep_list.append(self)

    def sua(voi_bep_list, ma):
        for sp in voi_bep_list:
            if sp.ma == ma:
                super(VoiBep, sp).sua(voi_bep_list, ma)
                print("9. Tính năng sản phẩm")
                print("10. Vật liệu sản phẩm")
                print("11. Bề mặt sản phẩm")
                print("12. Lưới lọc sản phẩm")

                chon = input("Chọn chức năng: ")
                if chon == "9":
                    sp.tinh_nang = input("Nhập tính năng sản phẩm: ")
                elif chon == "10":
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm: ")
                elif chon == '11':
                    sp.be_mat = input("Nhập bề mặt sản phẩm: ")
                elif chon == '12':
                    sp.luoi_loc = input("Nhập lưới lọc sản phẩm: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(voi_bep_list, id):
        for sp in voi_bep_list:
            if sp.id == id:
                voi_bep_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(voi_bep_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in voi_bep_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                super(ThietBiNhaBep, sp).tim_kiem()
                print(f"Lưới lọc: {sp.luoi_loc}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class ChauRuaChen (ThietBiNhaBep):
    chau_rua_chen_list = []
    def __init__(self, id, name, category, quantity, price, describe, image, color, brand, features, material, surface_finish, surface_dimensions, cutout_dimensions):
        super().__init__(id, name, category, quantity, price, describe, image, color, brand, features, material, surface_finish)
        self.kt_be_mat = surface_dimensions
        self.kt_khoet_da = cutout_dimensions

    def nhap(self):
        super().nhap()
        self.kt_be_mat = input("Nhập kích thước bề mặt: ")
        self.kt_khoet_da = input("Nhập kích thước khoét đá")
        ChauRuaChen.chau_rua_chen_list.append(self)

    def sua(chau_rua_chen_list, ma):
        for sp in chau_rua_chen_list:
            if sp.ma == ma:
                super(ChauRuaChen, sp).sua(chau_rua_chen_list, ma)
                print("12. Kích thước bề mặt sản phẩm")
                print("13. Kích thước khoét đá sản phẩm")

                chon = input("Chọn chức năng: ")
                if chon == '12':
                    sp.kt_be_mat = input("Nhập kích thước bề mặt sản phẩm")
                elif chon == '13':
                    sp.kt_khoet_da = input("Nhập kích thước khoét đá sản phẩm: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(chau_rua_chen_list, ma):
        for sp in chau_rua_chen_list:
            if sp.ma == ma:
                chau_rua_chen_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(chau_rua_chen_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in chau_rua_chen_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                super(GachOpLat, sp).tim_kiem()
                print(f"Kích thước bề mặt: {sp.kt_be_mat}")
                print(f"Kích thước khoét đá: {sp.kt_khoet_da}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class GachOpLat(SanPham):
    gach_list = []
    def __init__(self, id, name, category, quantity, price, describe,image, color, brand, features, dimensions, pattern, surface_finish, glaze_type, tile_type, tile_body, packaging_specification):
        super().__init__(id, name, category, quantity, price, describe,image, color, brand )
        self.tinh_nang = features
        self.kich_thuoc = dimensions
        self.hoa_tiet = pattern
        self.be_mat = surface_finish
        self.loai_men = glaze_type
        self.loai_gach = tile_type
        self.xuong_gach = tile_body
        self.quy_cach_dong_goi = packaging_specification

    def nhap(self, gach_list):
        super().nhap()
        self.tinh_nang = input("Nhập tính năng sản phẩm: ")
        self.kich_thuoc = input("Nhập kích thước sản phẩm: ")
        self.hoa_tiet = input("Nhập họa tiết sản phẩm: ")
        self.be_mat = input("Nhập bề mặt sản phẩm: ")
        self.loai_men = input("Nhập loại men sản phẩm: ")
        self.loai_gach = input("Nhập loại gạch của sản phẩm")
        self.xuong_gach = input("Nhập xương gạch của sản phẩm:")
        self.quy_cach_dong_goi = input("Nhập quy cách đóng gói sản phẩm")
        GachOpLat.gach_list.append(self)

    def sua(gach_list, ma):
        for sp in gach_list:
            if sp.ma == ma:
                super(GachOpLat, sp).sua(gach_list, ma)
                print("9. Tính năng sản phẩm: ")
                print("10. Kích thươc sản phẩm: ")
                print("11. Hoạ tiết sản phẩm: ")
                print("12. Bề mặt sản phẩm: ")
                print("13. Loại men sản phẩm: ")
                print("14. Loại gạch sản phẩm: ")
                print("15. Xương gạch sản phẩm: ")
                print("16. Quy cách đóng gói sản phẩm: ")

                chon = input("Chọn chức năng: ")
                if chon == '9':
                    sp.tinh_nang = input("Nhập tính năng sản phẩm: ")
                elif chon == '10':
                    sp.tinh_nang = input("Nhập kích thước sản phẩm: ")
                elif chon == '11':
                    sp.tinh_nang = input("Nhập họa tiết sản phẩm: ")
                elif chon == '12':
                    sp.tinh_nang = input("Nhập bề mặt sản phẩm: ")
                elif chon == '13':
                    sp.tinh_nang = input("Nhập loại men sản phẩm: ")
                elif chon == '14':
                    sp.tinh_nang = input("Nhập loại gạch sản phẩm: ")
                elif chon == '15':
                    sp.tinh_nang = input("Nhập xương gạch sản phẩm: ")
                elif chon == '16':
                    sp.tinh_nang = input("Nhập quy cách đóng gói sản phẩm: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(gach_list, ma):
        for sp in gach_list:
            if sp.ma == ma:
                gach_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    def tim_kiem(gach_list, keyword):
        found_items = []
        print("\n--- KẾT QUẢ TÌM KIẾM ---")
        for sp in gach_list:
            if keyword.lower() in sp.ten.lower() or keyword.lower() in sp.ma():
                super(GachOpLat, sp).tim_kiem()
                print(f"Tính năng: {sp.tinh_nang} ")
                print(f"Kích thước: {sp.kich_thuoc}")
                print(f"Hoạ tiết: {sp.hoa_tiet}")
                print(f"Bề mặt: {sp.be_mat}")
                print(f"Loại men: {sp.loai_men}")
                print(f"Loại gạch: {sp.loai_gach}")
                print(f"Xương gạch: {sp.xuong_gach}")
                print(f"Quy cách đóng gói: {sp.quy_cach_dong_goi}")
                found_items.append(sp)
        if not found_items:
            print("Không tìm thấy sản phẩm!")
        return found_items

class BanCau(ThietBiVS):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, flush_system, glaze_technology, flush_technology, flush_mode, water_consumption, voltage, color):
        super().__init__(id, name, category, quantity, price, describe, image, brand)
        self.he_thong_xa = flush_system
        self.cong_nghe_men = glaze_technology
        self.cong_nghe_xa = flush_technology
        self.che_do_xa = flush_mode
        self.luong_nuoc_xa = water_consumption
        self.nguon_dien = voltage
        self.mau_sac = color

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.he_thong_xa = input("Nhập hệ thống xả: ")
        self.cong_nghe_men = input("Nhập công nghệ men: ")
        self.cong_nghe_xa = input("Nhập công nghệ xả: ")
        self.che_do_xa = input("Nhập chế độ xả: ")
        while True:
            try:
                self.luong_nuoc_xa = float(input("Nhập lượng nước xả (L): "))
                break
            except ValueError:
                print("Vui lòng nhập một số hợp lệ.")
        while True:
            try:
                self.nguon_dien = int(input("Nhập nguồn điện (V): "))
                break
            except ValueError:
                print("Vui lòng nhập một số nguyên.")
        self.mau_sac = input("Nhập màu sắc: ")
        sp = BanCau(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.he_thong_xa, self.cong_nghe_men, self.cong_nghe_xa, self.che_do_xa, self.luong_nuoc_xa, self.nguon_dien, self.mau_sac)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Hệ thống xả sản phẩm")
                print("9. Công nghệ men sản phẩm")
                print("10. Công nghệ xả sản phẩm")
                print("11. Chế độ xả sản phẩm")
                print("12. Lượng nước xả sản phẩm")
                print("13. Nguồn điện sản phẩm")
                print("14. Màu sắc sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.he_thong_xa = input("Nhập hệ thống xả sản phẩm mới: ")
                elif chon == '9':
                    sp.cong_nghe_men = input("Nhập công nghệ men sản phẩm mới: ")
                elif chon == '10':
                    sp.cong_nghe_xa = input("Nhập công nghệ xả sản phẩm mới: ")
                elif chon == '11':
                    sp.che_do_xa = input("Nhập chế độ xả sản phẩm mới: ")
                elif chon == '12':
                    while True:
                        try:
                            sp.luong_nuoc_xa = float(input("Nhập lượng nước xả sản phẩm mới: "))
                            break
                        except ValueError:
                            print("Vui lòng nhập một số hợp lệ.")
                elif chon == '13':
                    while True:
                        try:
                            sp.nguon_dien = int(input("Nhập nguồn điện sản phẩm mới: "))
                            break
                        except ValueError:
                            print("Vui lòng nhập một số hợp lệ.")
                elif chon == '14':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Hệ thống xả: {sp.he_thong_xa}")
                print(f"Công nghệ men: {sp.cong_nghe_men}")
                print(f"Công nghệ xả: {sp.cong_nghe_xa}")
                print(f"Chế độ xả: {sp.che_do_xa}")
                print(f"Lượng nước xả: {sp.luong_nuoc_xa}")
                print(f"Nguồn điện: {sp.nguon_dien}")
                print(f"Màu sắc: {sp.mau_sac}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items

class BonTam(ThietBiVS):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, material, dimensions, color):
        super().__init__(id, name, category, quantity, price, describe, image, brand)
        self.vat_lieu = material
        self.kich_thuoc = dimensions
        self.mau_sac = color

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.vat_lieu = input("Nhập vật liệu: ")
        self.kich_thuoc = input("Nhập kích thước (ví dụ: 90x60x70): ")
        self.mau_sac = input("Nhập màu sắc: ")
        sp = BonTam(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.vat_lieu, self.kich_thuoc, self.mau_sac)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Vật liệu sản phẩm")
                print("9. Kích thước sản phẩm")
                print("10. Màu sắc sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm mới: ")
                elif chon == '9':
                    sp.kich_thuoc = input("Nhập kích thước sản phẩm mới (ví dụ: 80x90x70): ")
                elif chon == '10':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Kích thước: {sp.kich_thuoc}")
                print(f"Màu sắc: {sp.mau_sac}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items

class ChauRua(ThietBiVS):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, technology, accessories, color):
        super().__init__(id, name, category, quantity, price, describe, image, brand)
        self.cong_nge = technology
        self.phu_kien_di_kem = accessories
        self.mau_sac = color

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.cong_nghe = input("Nhập công nghệ: ")
        self.phu_kien_di_kem = input("Nhập phụ kiện đi kèm: ")
        self.mau_sac = input("Nhập màu sắc: ")
        sp = ChauRua(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.cong_nghe, self.phu_kien_di_kem, self.mau_sac)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Công nghệ sản phẩm")
                print("9. Phụ kiện đi kèm sản phẩm")
                print("10. Màu sắc sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.cong_nghe = input("Nhập công nghệ sản phẩm mới: ")
                elif chon == '9':
                    sp.phu_kien_di_kem = input("Nhập phụ kiện đi kèm sản phẩm mới: ")
                elif chon == '10':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Công nghệ: {sp.cong_nghe}")
                print(f"Phụ kiện đi kèm: {sp.phu_kien_di_kem}")
                print(f"Màu sắc: {sp.mau_sac}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items

class SenTam(ThietBiVS):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, shower_head, surface_finish, features, material, dimensions, color):
        super().__init__(id, name, category, quantity, price, describe, image, brand)
        self.bat_sen = shower_head
        self.be_mat = surface_finish
        self.tinh_nang = features
        self.vat_lieu = material
        self.kich_thuoc = dimensions
        self.mau_sac = color

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.bat_sen = input("Nhập bát sen: ")
        self.be_mat = input("Nhập bề mặt: ")
        self.tinh_nang = input("Nhập tính năng: ")
        self.vat_lieu = input("Nhập vật liệu: ")
        self.kich_thuoc = input("Nhập kích thước: ")
        self.mau_sac = input("Nhập màu sắc: ")
        sp = SenTam(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.bat_sen, self.be_mat, self.tinh_nang, self.vat_lieu, self.kich_thuoc, self.mau_sac)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Bát sen sản phẩm")
                print("9. Bề mặt sản phẩm")
                print("10. Tính năng sản phẩm")
                print("11. Vật liệu sản phẩm")
                print("12. Kích thước sản phẩm")
                print("13. Màu sắc sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.bat_sen = input("Nhập bát sen sản phẩm mới: ")
                elif chon == '9':
                    sp.be_mat = input("Nhập bề mặt sản phẩm mới: ")
                elif chon == '10':
                    sp.tinh_nang = input("Nhập tính năng sản phẩm mới: ")
                elif chon == '11':
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm mới: ")
                elif chon == '12':
                    sp.kich_thuoc = input("Nhập kích thước sản phẩm mới: ")
                elif chon == '13':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Bát sen: {sp.bat_sen}")
                print(f"Bề mặt: {sp.be_mat}")
                print(f"Tính năng: {sp.tinh_nang}")
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Kích thước: {sp.kich_thuoc}")
                print(f"Màu sắc: {sp.mau_sac}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items

class Voi(ThietBiVS):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, material, color):
        super().__init__(id, name, category, quantity, price, describe, image, brand)
        self.vat_lieu = material
        self.mau_sac = color

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.vat_lieu = input("Nhập vật liệu: ")
        self.mau_sac = input("Nhập màu sắc: ")
        sp = Voi(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.vat_lieu, self.mau_sac)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Vật liệu sản phẩm")
                print("9. Màu sắc sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm mới: ")
                elif chon == '9':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Màu sắc: {sp.mau_sac}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items


class VoiChau(Voi):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, material, color, surface_finish, temperature_mixer, dimensions):
        super().__init__(id, name, category, quantity, price, describe, image, brand, material, color)
        self.be_mat = surface_finish
        self.bo_tron_nhiet_do = temperature_mixer
        self.kich_thuoc = dimensions

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.be_mat = input("Nhập bề mặt: ")
        self.bo_tron_nhiet_do = input("Nhập bộ trộn nhiệt độ: ")
        self.kich_thuoc = input("Nhập kích thước (ví dụ: 90x60x70): ")
        sp = VoiChau(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.material, self.color, self.be_mat, self.bo_tron_nhiet_do, self.kich_thuoc)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Vật liệu sản phẩm")
                print("9. Màu sắc sản phẩm")
                print("10. Bề mặt sản phẩm")
                print("11. Bộ trộn nhiệt độ sản phẩm")
                print("12. Kích thước sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm mới: ")
                elif chon == '9':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                elif chon == '10':
                    sp.be_mat = input("Nhập bề mặt sản phẩm mới: ")
                elif chon == '11':
                    sp.bo_tron_nhiet_do = input("Nhập bộ trộn nhiệt độ sản phẩm mới: ")
                elif chon == '12':
                    sp.kich_thuoc = input("Nhập kích thước sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Màu sắc: {sp.mau_sac}")
                print(f"Bề mặt: {sp.be_mat}")
                print(f"Bộ trộn nhiệt độ: {sp.bo_tron_nhiet_do}")
                print(f"Kích thước: {sp.kich_thuoc}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items


class Xit(Voi):
    def __init__(self, id, name, category, quantity, price, describe, image, brand, material, color, valve_core):
        super().__init__(id, name, category, quantity, price, describe, image, brand, material, color)
        self.van_loi = valve_core

    def nhap(self, thiet_bi_vs_list):
        super().nhap()
        self.van_loi = input("Nhập van lõi: ")
        sp = Xit(self.id, self.name, self.category, self.quantity, self.price, self.describe, self.image, self.brand, self.material, self.color, self.van_loi)
        thiet_bi_vs_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    def sua(self, thiet_bi_vs_list, id):
        for sp in thiet_bi_vs_list:
            if sp.ma == id:
                super().sua(thiet_bi_vs_list, id)
                print("8. Vật liệu sản phẩm")
                print("9. Màu sắc sản phẩm")
                print("10. Van lõi sản phẩm")
                chon = input("Chọn chức năng: ")
                if chon == '8':
                    sp.vat_lieu = input("Nhập vật liệu sản phẩm mới: ")
                elif chon == '9':
                    sp.mau_sac = input("Nhập màu sắc sản phẩm mới: ")
                elif chon == '10':
                    sp.van_loi = input("Nhập van lõi sản phẩm mới: ")
                else:
                    print("Chức năng không hợp lệ!")
                    return
                print("Sản phẩm đã được sửa!")
                return
        print("Sản phẩm không tồn tại!")

    def xoa(self, thiet_bi_vs_list, id):
        super().xoa(thiet_bi_vs_list, id)

    def tim_kiem(self, thiet_bi_vs_list, keyword):
        found_items = super().tim_kiem(thiet_bi_vs_list, keyword)
        if found_items:
            for sp in found_items:
                print(f"Vật liệu: {sp.vat_lieu}")
                print(f"Màu sắc: {sp.mau_sac}")
                print(f"Van lõi: {sp.van_loi}")
        else:
            print("Không tìm thấy sản phẩm!")
        return found_items


class PhuKienKhac(SanPham):

    def __init__(self, id, name, category, quantity, price, describe, brand):
        super().__init__(id, name, category, quantity, price, describe, brand)

    def hien_thi_thong_tin(self):
        super().hien_thi_thong_tin()

    @staticmethod
    # Phương thức nhập thông tin sản phẩm
    def nhap_thong_tin_sp(self, san_pham_list):
        while True:
            id = super().nhap_thong_tin_sp()
            if any(sp.ma == id for sp in san_pham_list):
                print(f"Mã sản phẩm '{id}' đã tồn tại. Vui lòng nhập lại!")
            else:
                break
        super().nhap_thong_tin_sp(id, name, category, quantity, price, describe, brand)
        # Tạo đối tượng sản phẩm và thêm vào danh sách
        sp = PhuKienKhac(id, name, category, quantity, price, describe, brand)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách")

    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")


    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

class GaThoatSan(PhuKienKhac):
    def __init__(self, id, name, category, quantity, price, describe, brand):
        super().__init__(id, name, category, quantity, price, describe, brand)

    def hien_thi_thong_tin(self):
        return super().hien_thi_thong_tin()

    @staticmethod
    # Phương thức nhập thông tin sản phẩm
    def nhap_thong_tin_sp(self, san_pham_list):
        while True:
            id = super().nhap_thong_tin_sp()
            if any(sp.ma == id for sp in san_pham_list):
                print(f"Mã sản phẩm '{id}' đã tồn tại. Vui lòng nhập lại!")
            else:
                break
        super().nhap_thong_tin_sp(id, name, category, quantity, price, describe, brand)
        sp = GaThoatSan(id, name, category, quantity, price, describe, brand)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách")

    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

class Guong(PhuKienKhac):
    kich_thuoc = ''
    hinh_dang = ''


    def __init__(self, id, name, category, quantity, price, describe, brand, material, shape):
        super().__init__(id, name, category, quantity, price, describe, brand)
        self.kich_thuoc = material
        self.hinh_dang = shape

    @staticmethod
    def hien_thi_thong_tin(self):
        super().hien_thi_thong_tin()
        print(f"Kích thước: {self.kich_thuoc}")
        print("\n".join([
            f"{attr.replace('_', ' ').capitalize()}: {value}"
            for attr, value in self.__dict__.items()
            if value  # Chỉ hiển thị thuộc tính có giá trị
        ]))

    @staticmethod
    #Phương thức nhập thông tin sản phẩm
    def nhap_thong_tin_sp(self, san_pham_list):
        material = input(f"Nhập kích thước sản phẩm: ")
        shape = input("Nhập hình dạng sản phẩm: ")
        self.kich_thuoc = material
        sp = Guong(id, name, category, quantity, price, describe, brand, material, shape)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách!")

    @staticmethod
    # Phương thức sửa thông tin sản phẩm
    def sua_thong_tin_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                print("Chọn thông tin cần sửa: ")
                print("1. Kích thước")
                chon = input("Chọn thông tin cần sửa: ")
                if chon == '1':
                    sp.kich_thuoc = input("Nhập kích thước mới: ")
                elif chon == '2':
                    sp.hinh_dang = input("Nhập hình dạng mới: ")
                else:
                    print("Thông tin cần sửa không hợp lệ!")
                    return
                print("Đã cập nhật thông tin sản phẩm!")
                return
        print("Sản phẩm không tồn tại")

    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

class LoGiayVeSinh(PhuKienKhac):
    def __init__(self, id, name, category, quantity, price, describe, brand):
        super().__init__(id, name, category, quantity, price, describe, brand)

    def hien_thi_thong_tin(self):
        super().hien_thi_thong_tin()

    def nhap_thong_tin_sp(self, san_pham_list):
        super().nhap_thong_tin_sp(id, name, category, quantity, price, describe, brand)
        sp = LoGiayVeSinh(id, name, category, quantity, price, describe, brand)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm vào danh sách")

    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

class NapRuaDienTu(PhuKienKhac):
    nap_bet = ''
    voi_phun = ''
    che_do_xa = ''
    tinh_nang = ''

    def __init__(self, id, name, category, quantity, price, describe, brand, nozzle, features, toilet_seat, flush_technology):
        super().__init__(id, name, category, quantity, price, describe, brand)
        self.nap_bet = toilet_seat
        self.voi_phun = nozzle
        self.che_do_xa = flush_technology
        self.tinh_nang = features

    def hien_thi_thong_tin(self):
        super().hien_thi_thong_tin()
        print(f"Nắp bệt: {self.nap_bet}")
        print(f"Vòi phun: {self.voi_phun}")
        print(f"Chế độ: {self.che_do_xa}")
        print(f"Tính năng: {self.tinh_nang}")

    def nhap_thong_tin_sp(self, san_pham_list):
        super().nhap_thong_tin_sp(san_pham_list)
        toilet_seat = input("Nhập loại nắp bệt của sản phẩm: ")
        self.nap_bet = toilet_seat
        nozzle = input("Nhập loại vòi phun của sản phẩm")
        self.voi_phun = nozzle
        flush_technology = input("Nhập chế độ xả của sản phẩm: ")
        self.che_do_xa = flush_technology
        features = input("Nhập tính năng của sản phẩm: ")
        self.tinh_nang = features
        sp = NapRuaDienTu(id, name, category, quantity, price, describe, brand, nozzle, toilet_seat, features, flush_technology)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm!")

    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")

    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

    @staticmethod
    # Phương thức sửa thông tin sản phẩm
    def sua_thong_tin_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                print("Chọn thông tin cần sửa: ")
                print("1. Nắp bệt")
                print("2. Vòi phun")
                print("3. Chế độ xả")
                print("4. TÍnh năng")
                chon = input("Chọn thông tin cần sửa: ")
                if chon == '1':
                    sp.nap_bet = input("Nhập loại nắp bệt mới: ")
                elif chon == '2':
                    sp.voi_phun = input("Nhập loại vòi phun mới: ")
                elif chon == '3':
                    sp.che_do_xa = input("Nhập chế độ xả mới: ")
                elif chon == '4':
                    sp.tinh_nang = input("Nhập tính năng mới: ")
                else:
                    print("Thông tin cần sửa không hợp lệ!")
                    return
                print("Đã cập nhật thông tin sản phẩm!")
                return
        print("Sản phẩm không tồn tại")


class PhuKien(PhuKienKhac):
    chat_lieu = ''


    def __init__(self, id, name, category, quantity, price, describe, brand, material):
        super().__init__(id, name, category, quantity, price, describe, brand)
        self.chat_lieu = material


    def hien_thi_thong_tin(self):
        super().hien_thi_thong_tin()
        print(f"Chất liệu: {self.chat_lieu}")


    @staticmethod
    def nhap_thong_tin_sp(self, san_pham_list):
        super().nhap_thong_tin_sp(san_pham_list)
        material = input("Nhập chất liệu của sản phẩm: ")
        self.chat_lieu = material
        sp = PhuKien(id, name, category, quantity, price, describe, brand, material)
        san_pham_list.append(sp)
        print("Sản phẩm đã được thêm!")


    @staticmethod
    # Phương thức xóa sản phẩm
    def xoa_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                san_pham_list.remove(sp)
                print("Sản phẩm đã được xóa!")
                return
        print("Sản phẩm không tồn tại!")


    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua

    @staticmethod
    # Phương thức tìm kiếm sản phẩm
    def tim_kiem_sp(san_pham_list, ma, id):
        ket_qua = []
        for sp in san_pham_list:
            if sp.ma == id:
                ket_qua.append(sp)
        if not ket_qua:
            print("Không tìm thấy sản phẩm!")
        return ket_qua


    @staticmethod
    # Phương thức sửa thông tin sản phẩm
    def sua_thong_tin_sp(san_pham_list, id, ma):
        for sp in san_pham_list:
            if sp.ma == id:
                print("Chọn thông tin cần sửa: ")
                print("1. Chất liệu")
                chon = input("Chọn thông tin cần sửa: ")
                if chon == '1':
                    sp.chat_lieu = input("Nhập loại nắp bệt mới: ")
                else:
                    print("Thông tin cần sửa không hợp lệ!")
                    return
                print("Đã cập nhật thông tin sản phẩm!")
                return
        print("Sản phẩm không tồn tại")

1
# Out:
# --- CHƯƠNG TRÌNH QUẢN LÝ KHO HÀNG ---
# 1. Quản lý sản phẩm
# 2. Quản lý người dùng
# 3. Quản lý phiếu nhập kho
# 4. Quản lý phiếu xuất kho
# 5. Quản lý kênh phân phối
# 6. Quản lý nhà cung cấp
# 0. Thoát chương trình
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-83bdbcdd8c8e> in <cell line: 2087>()
#    2085 # Khởi tạo chương trình và menu
#    2086 quan_ly_kho = Menu()
# -> 2087 quan_ly_kho.chon_menu()
#    2088
#    2089
#
# <ipython-input-2-83bdbcdd8c8e> in chon_menu(self)
#    1912         while True:
#    1913             self.hien_thi_menu()
# -> 1914             chon = input("Chọn chức năng: ")
#    1915             if chon == '1':
#    1916                 self.quan_ly_san_pham()
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
